# %% [markdown]
# ## TactiTrack

# %%
import cv2 
import numpy as np 
import os 

from ultralytics import YOLO
import supervision as sv 
from classifiers import *
from sklearn.cluster import KMeans
from collections import defaultdict
from classifiers import *
from visualization import *
from sklearn.cluster import KMeans
from interpolations import *

# %%
import cv2
import numpy as np
import os
from ultralytics import YOLO
from collections import defaultdict
from sklearn.cluster import KMeans
import supervision as sv
from classifiers import *
from visualization import *
from utils import *

# paths
input_video_path = 'input_videos/9.mp4'
output_video_path = 'output_videos/output.mp4'
model_path = 'models/best.pt'

# making video and readung 
cap = cv2.VideoCapture(input_video_path)
fps = cap.get(cv2.CAP_PROP_FPS)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
out = cv2.VideoWriter(output_video_path, cv2.VideoWriter_fourcc(*'mp4v'), fps, (width, height))

model = YOLO(model_path)
tracker = sv.ByteTrack()


# possession variables
team_possession = {0: 0, 1: 0}
current_possession = None
ball_holder = None
ball_hold_frames = 0
possession_threshold = 5
total_frames = 0

# additional variables
reference_colors = None
team_assignments = {}
color_history = defaultdict(list)
ball_positions_history = []
max_history_length = 10

# Team colors
TEAM_COLORS = {
    0: (0, 0, 255),  # Team 1 - Red
    1: (255, 0, 0),  # Team 2 - Blue
    "goalkeeper": (0, 0, 255),
    "referee": (0, 255, 255),
    "ball": (255, 255, 255)
}

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Step 1 detection 
    results = model(frame)[0]
    detections = sv.Detections.from_ultralytics(results)
    players = detections[detections.class_id == 2]
    goalkeepers = detections[detections.class_id == 1]
    referees = detections[detections.class_id == 3]
    ball = detections[detections.class_id == 0]

    # Step 2 classification based on jerse color 
    if len(players) > 0:
        grass_color = get_grass_color(frame)
        grass_hsv = cv2.cvtColor(np.uint8([[grass_color]]), cv2.COLOR_BGR2HSV)[0, 0]
        jersey_colors = [
            get_jersey_color(frame[int(y1):int(y2), int(x1):int(x2)], grass_hsv)
            for x1, y1, x2, y2 in players.xyxy
        ]
        
        # detect the team colors
        if len(jersey_colors) >= 2 and not reference_colors:
            kmeans = KMeans(n_clusters=2).fit(jersey_colors)
            reference_colors = {
                0: kmeans.cluster_centers_[0],
                1: kmeans.cluster_centers_[1],
            }

        # ربط اللاعبين بفرقهم
        teams = []
        for color in jersey_colors:
            if reference_colors:
                distances = [np.linalg.norm(color - ref) for ref in reference_colors.values()]
                team = distances.index(min(distances))
                teams.append(team)

    # Step 3 tracking 
    players = tracker.update_with_detections(players)

    for i, track_id in enumerate(players.tracker_id):
        if i < len(teams):
            color_history[track_id].append(teams[i])
            if len(color_history[track_id]) >= 5:
                assigned_team = max(set(color_history[track_id]), key=color_history[track_id].count)
                team_assignments[track_id] = assigned_team

    # Step 4 ball position interpolation 
    ball_bbox = None
    if len(ball.xyxy) > 0:
        ball_bbox = tuple(map(int, ball.xyxy[0]))
        ball_positions_history.append(ball_bbox)
    else:
        ball_positions_history.append(None)

    if len(ball_positions_history) > max_history_length:
        ball_positions_history.pop(0)

    if None in ball_positions_history:
        interpolated = interpolate_ball_positions(ball_positions_history)
        if interpolated[-1]:
            ball_bbox = interpolated[-1]

    #Step 5  calculate possession 
    closest_player = None
    min_distance = float('inf')

    if ball_bbox:
        ball_center = get_center_of_bbox(ball_bbox)
        for i, track_id in enumerate(players.tracker_id):
            player_center = get_center_of_bbox(players.xyxy[i])
            dist = np.linalg.norm(np.array(ball_center) - np.array(player_center))
            if dist < min_distance and dist < 40:
                min_distance = dist
                closest_player = track_id

        if closest_player:
            if closest_player == ball_holder:
                ball_hold_frames += 1
            else:
                ball_holder = closest_player
                ball_hold_frames = 1

            if ball_hold_frames >= possession_threshold:
                new_possession = team_assignments.get(ball_holder, None)
                if new_possession is not None:
                    current_possession = new_possession
                    team_possession[current_possession] += 1

    total_frames += 1

    # Step 6 drawing 
    annotated = frame.copy()

    # draw players
    for bbox, track_id in zip(players.xyxy, players.tracker_id):
        team = team_assignments.get(track_id, 0)
        has_ball = (track_id == ball_holder and ball_hold_frames >= possession_threshold)
        annotated = draw_annotation(annotated, bbox, TEAM_COLORS[team], track_id, team, has_ball)

    # draw ball
    if ball_bbox:
        draw_triangle(annotated, ball_bbox, TEAM_COLORS["ball"])

    # Draw possession
    if total_frames > 0:
        team_0_ratio = team_possession[0] / total_frames
        team_1_ratio = team_possession[1] / total_frames
        total_ratio = team_0_ratio + team_1_ratio
        team_0_possession = (team_0_ratio / total_ratio) * 100 if total_ratio > 0 else 50
        team_1_possession = 100 - team_0_possession

        possession_text = f"Team {current_possession + 1} has possession" if current_possession is not None else "No possession"
        annotated = add_transparent_rectangle(annotated, width - 400, height - 130, width - 10, height - 10, (192, 192, 192), 0.7)
        cv2.putText(annotated, f"Team 1: {team_0_possession:.1f}%", (width - 350, height - 100), cv2.FONT_HERSHEY_SIMPLEX, 1, TEAM_COLORS[0], 2)
        cv2.putText(annotated, f"Team 2: {team_1_possession:.1f}%", (width - 350, height - 60), cv2.FONT_HERSHEY_SIMPLEX, 1, TEAM_COLORS[1], 2)
        cv2.putText(annotated, possession_text, (width - 350, height - 20), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 255, 255), 2)

 
    out.write(annotated)

cap.release()
out.release()
print("✅ Processing complete.")
os.system(f'start {output_video_path}')
# Out:
# 0: 384x640 2 goalkeepers, 17 players, 4 referees, 42.8ms
# Speed: 6.1ms preprocess, 42.8ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 20 players, 3 referees, 38.2ms
# Speed: 4.4ms preprocess, 38.2ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 20 players, 3 referees, 37.2ms
# Speed: 3.4ms preprocess, 37.2ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 18 players, 3 referees, 37.3ms
# Speed: 3.8ms preprocess, 37.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 17 players, 2 referees, 37.5ms
# Speed: 4.4ms preprocess, 37.5ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 18 players, 2 referees, 37.5ms
# Speed: 2.8ms preprocess, 37.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 19 players, 1 referee, 37.5ms
# Speed: 3.4ms preprocess, 37.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 20 players, 1 referee, 38.1ms
# Speed: 3.6ms preprocess, 38.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 20 players, 1 referee, 37.7ms
# Speed: 4.7ms preprocess, 37.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 18 players, 2 referees, 37.7ms
# Speed: 4.8ms preprocess, 37.7ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 20 players, 1 referee, 37.9ms
# Speed: 4.6ms preprocess, 37.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 18 players, 2 referees, 37.8ms
# Speed: 2.7ms preprocess, 37.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 15 players, 2 referees, 37.3ms
# Speed: 2.7ms preprocess, 37.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 15 players, 2 referees, 39.5ms
# Speed: 6.2ms preprocess, 39.5ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 14 players, 2 referees, 39.0ms
# Speed: 2.7ms preprocess, 39.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 16 players, 2 referees, 39.1ms
# Speed: 3.3ms preprocess, 39.1ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 15 players, 1 referee, 41.1ms
# Speed: 2.7ms preprocess, 41.1ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 17 players, 1 referee, 40.1ms
# Speed: 3.0ms preprocess, 40.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 15 players, 1 referee, 39.7ms
# Speed: 3.0ms preprocess, 39.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 16 players, 1 referee, 39.5ms
# Speed: 2.4ms preprocess, 39.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 2 goalkeepers, 18 players, 1 referee, 39.9ms
# Speed: 2.6ms preprocess, 39.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 15 players, 1 referee, 40.7ms
# Speed: 3.4ms preprocess, 40.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 17 players, 2 referees, 40.6ms
# Speed: 4.0ms preprocess, 40.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 18 players, 3 referees, 42.4ms
# Speed: 2.4ms preprocess, 42.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 2 goalkeepers, 19 players, 2 referees, 40.9ms
# Speed: 3.1ms preprocess, 40.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 19 players, 2 referees, 41.5ms
# Speed: 3.7ms preprocess, 41.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 2 referees, 40.5ms
# Speed: 2.7ms preprocess, 40.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 2 goalkeepers, 18 players, 2 referees, 41.9ms
# Speed: 3.8ms preprocess, 41.9ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 17 players, 3 referees, 41.7ms
# Speed: 5.0ms preprocess, 41.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 17 players, 2 referees, 42.1ms
# Speed: 3.3ms preprocess, 42.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 17 players, 2 referees, 42.2ms
# Speed: 2.7ms preprocess, 42.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 2 goalkeepers, 19 players, 3 referees, 41.3ms
# Speed: 2.7ms preprocess, 41.3ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 20 players, 3 referees, 41.1ms
# Speed: 3.5ms preprocess, 41.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 2 goalkeepers, 20 players, 3 referees, 42.9ms
# Speed: 3.1ms preprocess, 42.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 19 players, 3 referees, 41.0ms
# Speed: 4.0ms preprocess, 41.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 2 goalkeepers, 18 players, 3 referees, 41.3ms
# Speed: 3.0ms preprocess, 41.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 2 goalkeepers, 17 players, 3 referees, 43.2ms
# Speed: 4.3ms preprocess, 43.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 19 players, 3 referees, 40.9ms
# Speed: 3.1ms preprocess, 40.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 19 players, 3 referees, 41.1ms
# Speed: 2.9ms preprocess, 41.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 18 players, 3 referees, 41.2ms
# Speed: 3.8ms preprocess, 41.2ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 2 referees, 41.3ms
# Speed: 3.6ms preprocess, 41.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 20 players, 2 referees, 42.0ms
# Speed: 2.7ms preprocess, 42.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 2 goalkeepers, 20 players, 2 referees, 41.2ms
# Speed: 2.3ms preprocess, 41.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 20 players, 2 referees, 40.5ms
# Speed: 3.3ms preprocess, 40.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 19 players, 2 referees, 40.8ms
# Speed: 4.8ms preprocess, 40.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 18 players, 2 referees, 40.2ms
# Speed: 3.9ms preprocess, 40.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 18 players, 3 referees, 42.2ms
# Speed: 3.5ms preprocess, 42.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 17 players, 3 referees, 40.7ms
# Speed: 4.6ms preprocess, 40.7ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 17 players, 3 referees, 40.8ms
# Speed: 4.2ms preprocess, 40.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 2 goalkeepers, 18 players, 3 referees, 41.1ms
# Speed: 3.8ms preprocess, 41.1ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 17 players, 3 referees, 40.2ms
# Speed: 3.5ms preprocess, 40.2ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 2 goalkeepers, 17 players, 3 referees, 41.0ms
# Speed: 3.2ms preprocess, 41.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 2 goalkeepers, 18 players, 4 referees, 41.0ms
# Speed: 4.0ms preprocess, 41.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 19 players, 3 referees, 42.4ms
# Speed: 2.9ms preprocess, 42.4ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 19 players, 3 referees, 41.0ms
# Speed: 3.2ms preprocess, 41.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 18 players, 3 referees, 40.6ms
# Speed: 3.5ms preprocess, 40.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 17 players, 3 referees, 40.9ms
# Speed: 3.7ms preprocess, 40.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 17 players, 3 referees, 40.6ms
# Speed: 3.6ms preprocess, 40.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 19 players, 3 referees, 40.2ms
# Speed: 3.0ms preprocess, 40.2ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 19 players, 3 referees, 41.7ms
# Speed: 2.6ms preprocess, 41.7ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 19 players, 3 referees, 41.1ms
# Speed: 3.4ms preprocess, 41.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 18 players, 3 referees, 40.5ms
# Speed: 2.8ms preprocess, 40.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 19 players, 3 referees, 42.4ms
# Speed: 2.5ms preprocess, 42.4ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 18 players, 3 referees, 40.4ms
# Speed: 3.4ms preprocess, 40.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 20 players, 3 referees, 41.8ms
# Speed: 3.5ms preprocess, 41.8ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 18 players, 3 referees, 44.5ms
# Speed: 3.2ms preprocess, 44.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 2 goalkeepers, 17 players, 2 referees, 43.8ms
# Speed: 3.3ms preprocess, 43.8ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 2 goalkeepers, 18 players, 3 referees, 40.7ms
# Speed: 5.3ms preprocess, 40.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 18 players, 3 referees, 43.5ms
# Speed: 5.0ms preprocess, 43.5ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 19 players, 3 referees, 42.0ms
# Speed: 3.7ms preprocess, 42.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 2 goalkeepers, 19 players, 3 referees, 40.3ms
# Speed: 2.6ms preprocess, 40.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 19 players, 3 referees, 40.7ms
# Speed: 2.6ms preprocess, 40.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 18 players, 3 referees, 40.5ms
# Speed: 2.7ms preprocess, 40.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 18 players, 3 referees, 40.5ms
# Speed: 2.6ms preprocess, 40.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 2 goalkeepers, 18 players, 2 referees, 40.4ms
# Speed: 3.4ms preprocess, 40.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 20 players, 2 referees, 40.9ms
# Speed: 2.9ms preprocess, 40.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 21 players, 2 referees, 40.4ms
# Speed: 3.1ms preprocess, 40.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 20 players, 2 referees, 42.7ms
# Speed: 3.3ms preprocess, 42.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 20 players, 2 referees, 40.5ms
# Speed: 2.5ms preprocess, 40.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 18 players, 2 referees, 40.0ms
# Speed: 3.2ms preprocess, 40.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 1 referee, 42.2ms
# Speed: 3.1ms preprocess, 42.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 2 referees, 40.1ms
# Speed: 2.8ms preprocess, 40.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 16 players, 3 referees, 42.3ms
# Speed: 3.8ms preprocess, 42.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 17 players, 3 referees, 41.9ms
# Speed: 3.1ms preprocess, 41.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 17 players, 3 referees, 41.9ms
# Speed: 2.4ms preprocess, 41.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 3 referees, 43.6ms
# Speed: 2.9ms preprocess, 43.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 3 referees, 42.3ms
# Speed: 3.2ms preprocess, 42.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 20 players, 3 referees, 40.9ms
# Speed: 2.5ms preprocess, 40.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 20 players, 3 referees, 41.0ms
# Speed: 4.3ms preprocess, 41.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 20 players, 3 referees, 40.5ms
# Speed: 2.5ms preprocess, 40.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 20 players, 3 referees, 40.3ms
# Speed: 3.6ms preprocess, 40.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 19 players, 3 referees, 40.5ms
# Speed: 3.1ms preprocess, 40.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 18 players, 3 referees, 41.9ms
# Speed: 2.8ms preprocess, 41.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 3 referees, 40.3ms
# Speed: 3.2ms preprocess, 40.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 40.2ms
# Speed: 2.9ms preprocess, 40.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 39.9ms
# Speed: 2.3ms preprocess, 39.9ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 3 referees, 41.7ms
# Speed: 2.2ms preprocess, 41.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 3 referees, 41.7ms
# Speed: 2.4ms preprocess, 41.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 3 referees, 40.0ms
# Speed: 2.5ms preprocess, 40.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 3 referees, 40.2ms
# Speed: 2.5ms preprocess, 40.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 18 players, 3 referees, 40.2ms
# Speed: 2.5ms preprocess, 40.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 3 referees, 39.6ms
# Speed: 2.2ms preprocess, 39.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 3 referees, 39.9ms
# Speed: 2.5ms preprocess, 39.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 3 referees, 39.7ms
# Speed: 2.3ms preprocess, 39.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 3 referees, 39.8ms
# Speed: 2.5ms preprocess, 39.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 3 referees, 40.2ms
# Speed: 2.4ms preprocess, 40.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 2 referees, 40.2ms
# Speed: 2.4ms preprocess, 40.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 2 referees, 40.0ms
# Speed: 3.0ms preprocess, 40.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 3 referees, 39.9ms
# Speed: 2.5ms preprocess, 39.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 3 referees, 40.2ms
# Speed: 2.8ms preprocess, 40.2ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 3 referees, 41.6ms
# Speed: 2.9ms preprocess, 41.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 3 referees, 39.8ms
# Speed: 3.0ms preprocess, 39.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 3 referees, 40.0ms
# Speed: 2.6ms preprocess, 40.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 3 referees, 39.9ms
# Speed: 2.6ms preprocess, 39.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 3 referees, 39.8ms
# Speed: 2.4ms preprocess, 39.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 3 referees, 40.1ms
# Speed: 2.5ms preprocess, 40.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 3 referees, 40.1ms
# Speed: 2.2ms preprocess, 40.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 3 referees, 40.1ms
# Speed: 2.3ms preprocess, 40.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 3 referees, 40.0ms
# Speed: 2.3ms preprocess, 40.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 3 referees, 39.5ms
# Speed: 2.9ms preprocess, 39.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 3 referees, 39.7ms
# Speed: 2.4ms preprocess, 39.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 19 players, 3 referees, 39.4ms
# Speed: 2.3ms preprocess, 39.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 3 referees, 39.9ms
# Speed: 2.5ms preprocess, 39.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 40.0ms
# Speed: 2.6ms preprocess, 40.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 40.0ms
# Speed: 2.3ms preprocess, 40.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 21 players, 3 referees, 39.6ms
# Speed: 2.3ms preprocess, 39.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 39.9ms
# Speed: 2.7ms preprocess, 39.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 2 referees, 39.9ms
# Speed: 3.5ms preprocess, 39.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 21 players, 3 referees, 40.0ms
# Speed: 2.4ms preprocess, 40.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 3 referees, 40.2ms
# Speed: 2.5ms preprocess, 40.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 3 referees, 39.7ms
# Speed: 2.0ms preprocess, 39.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 40.2ms
# Speed: 2.0ms preprocess, 40.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 2 referees, 40.0ms
# Speed: 2.5ms preprocess, 40.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 39.9ms
# Speed: 2.4ms preprocess, 39.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 40.3ms
# Speed: 2.3ms preprocess, 40.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 3 referees, 42.1ms
# Speed: 2.0ms preprocess, 42.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 41.7ms
# Speed: 2.5ms preprocess, 41.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 41.6ms
# Speed: 2.2ms preprocess, 41.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 41.7ms
# Speed: 2.2ms preprocess, 41.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 41.0ms
# Speed: 2.3ms preprocess, 41.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 41.8ms
# Speed: 2.4ms preprocess, 41.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 1 referee, 41.7ms
# Speed: 2.4ms preprocess, 41.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 42.0ms
# Speed: 2.5ms preprocess, 42.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 39.8ms
# Speed: 3.2ms preprocess, 39.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 40.0ms
# Speed: 3.7ms preprocess, 40.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 39.7ms
# Speed: 2.5ms preprocess, 39.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 40.1ms
# Speed: 2.4ms preprocess, 40.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 39.8ms
# Speed: 2.4ms preprocess, 39.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 40.0ms
# Speed: 2.5ms preprocess, 40.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 2 referees, 39.9ms
# Speed: 2.5ms preprocess, 39.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 40.1ms
# Speed: 2.3ms preprocess, 40.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 40.9ms
# Speed: 2.5ms preprocess, 40.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 42.0ms
# Speed: 2.4ms preprocess, 42.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 40.1ms
# Speed: 3.0ms preprocess, 40.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 42.3ms
# Speed: 2.8ms preprocess, 42.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 39.9ms
# Speed: 2.1ms preprocess, 39.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 1 referee, 39.5ms
# Speed: 2.4ms preprocess, 39.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 39.9ms
# Speed: 2.3ms preprocess, 39.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 40.0ms
# Speed: 2.5ms preprocess, 40.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 39.3ms
# Speed: 2.4ms preprocess, 39.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 39.8ms
# Speed: 2.7ms preprocess, 39.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 39.8ms
# Speed: 2.6ms preprocess, 39.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 39.9ms
# Speed: 2.8ms preprocess, 39.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 39.8ms
# Speed: 3.1ms preprocess, 39.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 41.2ms
# Speed: 2.0ms preprocess, 41.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 39.9ms
# Speed: 2.5ms preprocess, 39.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 1 referee, 39.8ms
# Speed: 2.4ms preprocess, 39.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 39.7ms
# Speed: 2.2ms preprocess, 39.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 1 referee, 37.7ms
# Speed: 2.3ms preprocess, 37.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 1 referee, 39.3ms
# Speed: 2.4ms preprocess, 39.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 37.1ms
# Speed: 2.7ms preprocess, 37.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 37.1ms
# Speed: 2.1ms preprocess, 37.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 38.0ms
# Speed: 2.0ms preprocess, 38.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 36.7ms
# Speed: 2.4ms preprocess, 36.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 36.8ms
# Speed: 2.3ms preprocess, 36.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 35.2ms
# Speed: 2.1ms preprocess, 35.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 35.5ms
# Speed: 2.2ms preprocess, 35.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 35.6ms
# Speed: 2.4ms preprocess, 35.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 35.3ms
# Speed: 2.0ms preprocess, 35.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 35.6ms
# Speed: 2.4ms preprocess, 35.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 2 referees, 35.4ms
# Speed: 2.5ms preprocess, 35.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 2 referees, 35.3ms
# Speed: 2.1ms preprocess, 35.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 2 referees, 35.6ms
# Speed: 2.4ms preprocess, 35.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 2 referees, 35.6ms
# Speed: 2.1ms preprocess, 35.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 2 referees, 35.6ms
# Speed: 2.7ms preprocess, 35.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 2 referees, 35.9ms
# Speed: 2.4ms preprocess, 35.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 35.7ms
# Speed: 2.4ms preprocess, 35.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 2 referees, 35.5ms
# Speed: 2.4ms preprocess, 35.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 35.4ms
# Speed: 2.1ms preprocess, 35.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 37.0ms
# Speed: 2.3ms preprocess, 37.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 35.0ms
# Speed: 2.4ms preprocess, 35.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 34.8ms
# Speed: 2.4ms preprocess, 34.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 34.8ms
# Speed: 2.3ms preprocess, 34.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 34.7ms
# Speed: 2.3ms preprocess, 34.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 20 players, 1 referee, 34.6ms
# Speed: 2.2ms preprocess, 34.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 34.6ms
# Speed: 2.3ms preprocess, 34.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 20 players, 1 referee, 33.8ms
# Speed: 1.9ms preprocess, 33.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 20 players, 1 referee, 34.0ms
# Speed: 2.1ms preprocess, 34.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 34.2ms
# Speed: 2.2ms preprocess, 34.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 34.1ms
# Speed: 2.3ms preprocess, 34.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 20 players, 1 referee, 35.2ms
# Speed: 3.7ms preprocess, 35.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 19 players, 1 referee, 35.0ms
# Speed: 2.4ms preprocess, 35.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 19 players, 1 referee, 34.3ms
# Speed: 4.2ms preprocess, 34.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 1 referee, 34.6ms
# Speed: 2.8ms preprocess, 34.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 35.3ms
# Speed: 3.6ms preprocess, 35.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 34.1ms
# Speed: 2.6ms preprocess, 34.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 34.6ms
# Speed: 2.3ms preprocess, 34.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 34.5ms
# Speed: 2.2ms preprocess, 34.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 34.0ms
# Speed: 2.5ms preprocess, 34.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 35.2ms
# Speed: 3.7ms preprocess, 35.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 33.9ms
# Speed: 2.8ms preprocess, 33.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 35.6ms
# Speed: 2.6ms preprocess, 35.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 36.0ms
# Speed: 3.7ms preprocess, 36.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 1 referee, 34.9ms
# Speed: 2.6ms preprocess, 34.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 18 players, 1 referee, 35.9ms
# Speed: 2.8ms preprocess, 35.9ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 35.3ms
# Speed: 3.5ms preprocess, 35.3ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 35.1ms
# Speed: 3.0ms preprocess, 35.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 35.2ms
# Speed: 3.1ms preprocess, 35.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 35.9ms
# Speed: 2.6ms preprocess, 35.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 35.8ms
# Speed: 3.0ms preprocess, 35.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 38.3ms
# Speed: 3.4ms preprocess, 38.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 2 referees, 35.3ms
# Speed: 3.7ms preprocess, 35.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 2 referees, 35.0ms
# Speed: 3.1ms preprocess, 35.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 35.2ms
# Speed: 2.2ms preprocess, 35.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 37.2ms
# Speed: 3.1ms preprocess, 37.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 34.9ms
# Speed: 2.8ms preprocess, 34.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 37.1ms
# Speed: 2.5ms preprocess, 37.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 37.9ms
# Speed: 3.2ms preprocess, 37.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 39.0ms
# Speed: 2.6ms preprocess, 39.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 37.9ms
# Speed: 3.7ms preprocess, 37.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 38.1ms
# Speed: 2.3ms preprocess, 38.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 38.1ms
# Speed: 2.3ms preprocess, 38.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 38.6ms
# Speed: 2.2ms preprocess, 38.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 39.2ms
# Speed: 4.4ms preprocess, 39.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 39.9ms
# Speed: 2.9ms preprocess, 39.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 1 referee, 40.7ms
# Speed: 3.1ms preprocess, 40.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 39.3ms
# Speed: 3.8ms preprocess, 39.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 41.0ms
# Speed: 2.8ms preprocess, 41.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 18 players, 2 referees, 39.8ms
# Speed: 5.3ms preprocess, 39.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 17 players, 2 referees, 39.0ms
# Speed: 3.9ms preprocess, 39.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 18 players, 2 referees, 40.2ms
# Speed: 3.1ms preprocess, 40.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 39.5ms
# Speed: 2.4ms preprocess, 39.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 40.3ms
# Speed: 2.5ms preprocess, 40.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 39.9ms
# Speed: 2.6ms preprocess, 39.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 40.1ms
# Speed: 2.7ms preprocess, 40.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 39.6ms
# Speed: 2.2ms preprocess, 39.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 39.9ms
# Speed: 2.2ms preprocess, 39.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 2 referees, 39.9ms
# Speed: 2.4ms preprocess, 39.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 18 players, 2 referees, 40.1ms
# Speed: 2.9ms preprocess, 40.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 18 players, 2 referees, 40.1ms
# Speed: 2.3ms preprocess, 40.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 17 players, 1 referee, 40.5ms
# Speed: 3.8ms preprocess, 40.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 18 players, 1 referee, 40.3ms
# Speed: 2.8ms preprocess, 40.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 1 referee, 39.9ms
# Speed: 3.2ms preprocess, 39.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 2 referees, 40.1ms
# Speed: 2.2ms preprocess, 40.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 2 referees, 40.1ms
# Speed: 2.3ms preprocess, 40.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 2 referees, 40.3ms
# Speed: 2.5ms preprocess, 40.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 2 referees, 40.5ms
# Speed: 2.1ms preprocess, 40.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 40.2ms
# Speed: 2.3ms preprocess, 40.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 40.2ms
# Speed: 2.4ms preprocess, 40.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 40.4ms
# Speed: 3.0ms preprocess, 40.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 41.0ms
# Speed: 4.7ms preprocess, 41.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 41.8ms
# Speed: 3.0ms preprocess, 41.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 2 referees, 41.4ms
# Speed: 3.0ms preprocess, 41.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 19 players, 2 referees, 43.4ms
# Speed: 2.7ms preprocess, 43.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 2 referees, 41.1ms
# Speed: 2.9ms preprocess, 41.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 40.8ms
# Speed: 2.8ms preprocess, 40.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 41.9ms
# Speed: 6.6ms preprocess, 41.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 40.9ms
# Speed: 2.7ms preprocess, 40.9ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 40.7ms
# Speed: 2.6ms preprocess, 40.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 40.5ms
# Speed: 2.7ms preprocess, 40.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 40.6ms
# Speed: 2.4ms preprocess, 40.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 42.1ms
# Speed: 3.3ms preprocess, 42.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 40.4ms
# Speed: 2.5ms preprocess, 40.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 2 referees, 40.2ms
# Speed: 2.7ms preprocess, 40.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 2 referees, 40.5ms
# Speed: 2.2ms preprocess, 40.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 40.4ms
# Speed: 2.4ms preprocess, 40.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 19 players, 2 referees, 40.5ms
# Speed: 2.4ms preprocess, 40.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 40.2ms
# Speed: 2.3ms preprocess, 40.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 40.3ms
# Speed: 2.7ms preprocess, 40.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 40.4ms
# Speed: 2.4ms preprocess, 40.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 40.3ms
# Speed: 2.2ms preprocess, 40.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 40.3ms
# Speed: 2.2ms preprocess, 40.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 2 referees, 39.6ms
# Speed: 2.5ms preprocess, 39.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 19 players, 2 referees, 39.8ms
# Speed: 2.1ms preprocess, 39.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 39.7ms
# Speed: 1.9ms preprocess, 39.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 39.9ms
# Speed: 2.9ms preprocess, 39.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 41.2ms
# Speed: 2.0ms preprocess, 41.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 40.1ms
# Speed: 2.1ms preprocess, 40.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 2 referees, 39.9ms
# Speed: 2.1ms preprocess, 39.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 2 referees, 39.7ms
# Speed: 2.1ms preprocess, 39.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 40.1ms
# Speed: 2.3ms preprocess, 40.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 40.3ms
# Speed: 2.5ms preprocess, 40.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 2 referees, 39.9ms
# Speed: 2.1ms preprocess, 39.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 39.4ms
# Speed: 2.1ms preprocess, 39.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 38.9ms
# Speed: 3.6ms preprocess, 38.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 38.8ms
# Speed: 2.7ms preprocess, 38.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 39.1ms
# Speed: 2.1ms preprocess, 39.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 38.1ms
# Speed: 2.3ms preprocess, 38.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 37.4ms
# Speed: 2.6ms preprocess, 37.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 37.3ms
# Speed: 2.4ms preprocess, 37.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 37.3ms
# Speed: 2.4ms preprocess, 37.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 37.1ms
# Speed: 2.5ms preprocess, 37.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 36.0ms
# Speed: 2.5ms preprocess, 36.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 36.3ms
# Speed: 2.3ms preprocess, 36.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 36.2ms
# Speed: 2.5ms preprocess, 36.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 2 referees, 35.9ms
# Speed: 2.6ms preprocess, 35.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 36.3ms
# Speed: 2.4ms preprocess, 36.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 36.0ms
# Speed: 2.3ms preprocess, 36.0ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 35.8ms
# Speed: 2.4ms preprocess, 35.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 36.2ms
# Speed: 2.2ms preprocess, 36.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 36.2ms
# Speed: 2.4ms preprocess, 36.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 36.1ms
# Speed: 2.5ms preprocess, 36.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 36.3ms
# Speed: 2.5ms preprocess, 36.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 37.2ms
# Speed: 2.0ms preprocess, 37.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 36.0ms
# Speed: 2.1ms preprocess, 36.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 35.7ms
# Speed: 2.3ms preprocess, 35.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 35.5ms
# Speed: 2.2ms preprocess, 35.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 35.0ms
# Speed: 2.2ms preprocess, 35.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 34.8ms
# Speed: 2.1ms preprocess, 34.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# ...
#
# 0: 384x640 1 ball, 20 players, 2 referees, 35.0ms
# Speed: 2.6ms preprocess, 35.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 1 referee, 35.3ms
# Speed: 2.7ms preprocess, 35.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 35.2ms
# Speed: 2.5ms preprocess, 35.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 35.2ms
# Speed: 2.3ms preprocess, 35.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 35.4ms
# Speed: 2.6ms preprocess, 35.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 35.4ms
# Speed: 3.3ms preprocess, 35.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 35.6ms
# Speed: 3.8ms preprocess, 35.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 35.6ms
# Speed: 2.3ms preprocess, 35.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 35.5ms
# Speed: 2.5ms preprocess, 35.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 37.4ms
# Speed: 2.2ms preprocess, 37.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 37.6ms
# Speed: 2.5ms preprocess, 37.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 37.3ms
# Speed: 2.2ms preprocess, 37.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 37.5ms
# Speed: 2.2ms preprocess, 37.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 2 referees, 37.6ms
# Speed: 2.8ms preprocess, 37.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 1 referee, 38.1ms
# Speed: 3.8ms preprocess, 38.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 37.5ms
# Speed: 2.7ms preprocess, 37.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 2 referees, 38.9ms
# Speed: 2.4ms preprocess, 38.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 38.9ms
# Speed: 2.3ms preprocess, 38.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 37.9ms
# Speed: 2.3ms preprocess, 37.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 37.2ms
# Speed: 2.3ms preprocess, 37.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 2 referees, 37.1ms
# Speed: 2.0ms preprocess, 37.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 36.6ms
# Speed: 2.1ms preprocess, 36.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 2 referees, 37.9ms
# Speed: 2.8ms preprocess, 37.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 36.5ms
# Speed: 2.2ms preprocess, 36.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 2 referees, 36.8ms
# Speed: 2.2ms preprocess, 36.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 2 referees, 35.9ms
# Speed: 2.0ms preprocess, 35.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 2 referees, 35.3ms
# Speed: 2.5ms preprocess, 35.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 2 referees, 36.8ms
# Speed: 2.6ms preprocess, 36.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 34.4ms
# Speed: 2.1ms preprocess, 34.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 34.6ms
# Speed: 2.1ms preprocess, 34.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 2 referees, 34.5ms
# Speed: 2.0ms preprocess, 34.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 34.6ms
# Speed: 3.7ms preprocess, 34.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 34.8ms
# Speed: 2.0ms preprocess, 34.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 34.5ms
# Speed: 2.2ms preprocess, 34.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 1 referee, 35.1ms
# Speed: 2.1ms preprocess, 35.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 34.7ms
# Speed: 2.6ms preprocess, 34.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 2 referees, 34.5ms
# Speed: 2.3ms preprocess, 34.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 35.0ms
# Speed: 2.5ms preprocess, 35.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 35.2ms
# Speed: 3.1ms preprocess, 35.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 34.9ms
# Speed: 2.5ms preprocess, 34.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 35.1ms
# Speed: 2.8ms preprocess, 35.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 21 players, 1 referee, 34.7ms
# Speed: 2.6ms preprocess, 34.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 2 referees, 35.2ms
# Speed: 2.5ms preprocess, 35.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 35.2ms
# Speed: 2.2ms preprocess, 35.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 35.1ms
# Speed: 2.4ms preprocess, 35.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 1 referee, 34.7ms
# Speed: 2.5ms preprocess, 34.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 1 referee, 35.2ms
# Speed: 2.6ms preprocess, 35.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 35.5ms
# Speed: 2.6ms preprocess, 35.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 1 referee, 36.1ms
# Speed: 2.5ms preprocess, 36.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 36.1ms
# Speed: 3.1ms preprocess, 36.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 37.8ms
# Speed: 2.7ms preprocess, 37.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 37.4ms
# Speed: 2.3ms preprocess, 37.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 36.6ms
# Speed: 4.0ms preprocess, 36.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 36.4ms
# Speed: 2.3ms preprocess, 36.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 36.1ms
# Speed: 2.5ms preprocess, 36.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 37.9ms
# Speed: 2.2ms preprocess, 37.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 36.4ms
# Speed: 2.2ms preprocess, 36.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 36.5ms
# Speed: 2.2ms preprocess, 36.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 3 referees, 36.5ms
# Speed: 2.1ms preprocess, 36.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 3 referees, 36.7ms
# Speed: 1.9ms preprocess, 36.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 3 referees, 36.5ms
# Speed: 2.0ms preprocess, 36.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 3 referees, 36.9ms
# Speed: 2.4ms preprocess, 36.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 3 referees, 37.2ms
# Speed: 2.4ms preprocess, 37.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 3 referees, 37.1ms
# Speed: 2.3ms preprocess, 37.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 3 referees, 36.8ms
# Speed: 2.1ms preprocess, 36.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 19 players, 3 referees, 37.2ms
# Speed: 2.3ms preprocess, 37.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 3 referees, 38.2ms
# Speed: 3.2ms preprocess, 38.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 37.5ms
# Speed: 2.1ms preprocess, 37.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 21 players, 3 referees, 37.3ms
# Speed: 2.3ms preprocess, 37.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 3 referees, 37.0ms
# Speed: 2.1ms preprocess, 37.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 36.6ms
# Speed: 2.2ms preprocess, 36.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 36.5ms
# Speed: 2.2ms preprocess, 36.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 36.0ms
# Speed: 2.7ms preprocess, 36.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 36.4ms
# Speed: 2.4ms preprocess, 36.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 35.6ms
# Speed: 2.4ms preprocess, 35.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 3 referees, 35.4ms
# Speed: 2.3ms preprocess, 35.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 35.4ms
# Speed: 2.3ms preprocess, 35.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 35.6ms
# Speed: 2.8ms preprocess, 35.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 35.7ms
# Speed: 2.1ms preprocess, 35.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 35.2ms
# Speed: 2.8ms preprocess, 35.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 35.5ms
# Speed: 2.2ms preprocess, 35.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 3 referees, 35.8ms
# Speed: 3.3ms preprocess, 35.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 3 referees, 36.0ms
# Speed: 2.5ms preprocess, 36.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 35.7ms
# Speed: 2.9ms preprocess, 35.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 35.9ms
# Speed: 3.4ms preprocess, 35.9ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 19 players, 3 referees, 35.5ms
# Speed: 2.9ms preprocess, 35.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 3 referees, 35.9ms
# Speed: 2.4ms preprocess, 35.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 35.6ms
# Speed: 2.1ms preprocess, 35.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 35.1ms
# Speed: 3.2ms preprocess, 35.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 35.7ms
# Speed: 2.3ms preprocess, 35.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 35.4ms
# Speed: 2.5ms preprocess, 35.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 35.4ms
# Speed: 2.4ms preprocess, 35.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 3 referees, 36.2ms
# Speed: 2.1ms preprocess, 36.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 3 referees, 36.2ms
# Speed: 2.4ms preprocess, 36.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 3 referees, 36.4ms
# Speed: 2.1ms preprocess, 36.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 36.2ms
# Speed: 2.3ms preprocess, 36.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 36.4ms
# Speed: 2.2ms preprocess, 36.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 38.1ms
# Speed: 2.3ms preprocess, 38.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 38.0ms
# Speed: 2.5ms preprocess, 38.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 36.6ms
# Speed: 2.2ms preprocess, 36.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 37.0ms
# Speed: 2.6ms preprocess, 37.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 36.7ms
# Speed: 2.2ms preprocess, 36.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 36.8ms
# Speed: 2.2ms preprocess, 36.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 2 referees, 37.0ms
# Speed: 2.1ms preprocess, 37.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 37.2ms
# Speed: 2.1ms preprocess, 37.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 37.0ms
# Speed: 2.6ms preprocess, 37.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 3 referees, 36.6ms
# Speed: 2.5ms preprocess, 36.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 37.6ms
# Speed: 2.1ms preprocess, 37.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 36.4ms
# Speed: 2.3ms preprocess, 36.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 39.7ms
# Speed: 3.0ms preprocess, 39.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 36.5ms
# Speed: 2.9ms preprocess, 36.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 36.5ms
# Speed: 2.5ms preprocess, 36.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processing complete.
# 0

# %%
os.system('start output_videos/output.mp4')
# Out:
# 0

# %%
	import cv2
	import os 
	from ultralytics import YOLO

	# تحميل موديل pose
	model = YOLO('models/pitch_model.pt')  # اختار الموديل اللي شغال عندك

	# فتح ملف الفيديو\
	
	cap = cv2.VideoCapture("input_videos/2.mp4")  # غيّر للمسار الحقيقي للفيديو
	fps = cap.get(cv2.CAP_PROP_FPS)
	width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
	height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
	out = cv2.VideoWriter('output_videos/output.mp4', cv2.VideoWriter_fourcc(*'mp4v'), fps, (width, height))


	while cap.isOpened():
			ret, frame = cap.read()
			if not ret:
					break

			# تشغيل الموديل على الفريم
			results = model(frame)[0]

			if results.keypoints is not None:
					for kpts in results.keypoints.data:
							for i, (x, y, conf) in enumerate(kpts):
									x, y, conf = float(x), float(y), float(conf)
									if conf > 0.5:
											cv2.circle(frame, (int(x), int(y)), 5, (0, 255, 0), -1)
											
											cv2.putText(frame, str(i), (int(x) + 5, int(y) - 5),
																	cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 255), 2)
											
								

			out.write(frame)

	cap.release()
	out.release()
	cv2.destroyAllWindows()
	os.system('start output_videos/output.mp4')
# Out:
# 0: 384x640 1 pitch, 176.5ms
# Speed: 11.0ms preprocess, 176.5ms inference, 207.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 146.5ms
# Speed: 4.2ms preprocess, 146.5ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 146.4ms
# Speed: 3.4ms preprocess, 146.4ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 153.0ms
# Speed: 3.5ms preprocess, 153.0ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 163.5ms
# Speed: 4.2ms preprocess, 163.5ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 153.6ms
# Speed: 2.8ms preprocess, 153.6ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 145.1ms
# Speed: 2.3ms preprocess, 145.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 147.5ms
# Speed: 3.5ms preprocess, 147.5ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 155.8ms
# Speed: 2.9ms preprocess, 155.8ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 156.9ms
# Speed: 3.5ms preprocess, 156.9ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 156.3ms
# Speed: 4.3ms preprocess, 156.3ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 147.5ms
# Speed: 3.4ms preprocess, 147.5ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 146.9ms
# Speed: 3.4ms preprocess, 146.9ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 150.2ms
# Speed: 3.9ms preprocess, 150.2ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 145.8ms
# Speed: 3.4ms preprocess, 145.8ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 157.2ms
# Speed: 4.3ms preprocess, 157.2ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 154.9ms
# Speed: 3.9ms preprocess, 154.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 150.6ms
# Speed: 4.3ms preprocess, 150.6ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 145.4ms
# Speed: 4.1ms preprocess, 145.4ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 154.2ms
# Speed: 3.9ms preprocess, 154.2ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 153.5ms
# Speed: 4.2ms preprocess, 153.5ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 145.9ms
# Speed: 4.4ms preprocess, 145.9ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 156.3ms
# Speed: 3.4ms preprocess, 156.3ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 155.7ms
# Speed: 4.4ms preprocess, 155.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 150.8ms
# Speed: 3.6ms preprocess, 150.8ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 160.9ms
# Speed: 3.6ms preprocess, 160.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 150.0ms
# Speed: 3.6ms preprocess, 150.0ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 155.6ms
# Speed: 3.5ms preprocess, 155.6ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 151.0ms
# Speed: 3.9ms preprocess, 151.0ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 151.0ms
# Speed: 3.8ms preprocess, 151.0ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 153.3ms
# Speed: 4.0ms preprocess, 153.3ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 149.2ms
# Speed: 3.9ms preprocess, 149.2ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 147.1ms
# Speed: 3.7ms preprocess, 147.1ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 147.4ms
# Speed: 2.5ms preprocess, 147.4ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 153.0ms
# Speed: 3.9ms preprocess, 153.0ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 156.8ms
# Speed: 3.5ms preprocess, 156.8ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 140.3ms
# Speed: 4.0ms preprocess, 140.3ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 160.8ms
# Speed: 3.9ms preprocess, 160.8ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 154.6ms
# Speed: 3.8ms preprocess, 154.6ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 152.3ms
# Speed: 4.5ms preprocess, 152.3ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 155.5ms
# Speed: 3.2ms preprocess, 155.5ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 152.2ms
# Speed: 4.0ms preprocess, 152.2ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 150.7ms
# Speed: 3.4ms preprocess, 150.7ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 153.3ms
# Speed: 3.1ms preprocess, 153.3ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 154.9ms
# Speed: 4.9ms preprocess, 154.9ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 157.2ms
# Speed: 5.1ms preprocess, 157.2ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 155.0ms
# Speed: 3.5ms preprocess, 155.0ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 155.9ms
# Speed: 4.4ms preprocess, 155.9ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 155.6ms
# Speed: 3.5ms preprocess, 155.6ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 150.8ms
# Speed: 3.7ms preprocess, 150.8ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 155.9ms
# Speed: 4.1ms preprocess, 155.9ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 152.4ms
# Speed: 4.0ms preprocess, 152.4ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 155.8ms
# Speed: 4.3ms preprocess, 155.8ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 156.4ms
# Speed: 2.9ms preprocess, 156.4ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 151.8ms
# Speed: 3.2ms preprocess, 151.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 153.6ms
# Speed: 3.8ms preprocess, 153.6ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 153.8ms
# Speed: 4.0ms preprocess, 153.8ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 154.0ms
# Speed: 3.9ms preprocess, 154.0ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 154.4ms
# Speed: 4.4ms preprocess, 154.4ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 155.4ms
# Speed: 3.4ms preprocess, 155.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 150.1ms
# Speed: 2.7ms preprocess, 150.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 154.6ms
# Speed: 3.0ms preprocess, 154.6ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 146.1ms
# Speed: 2.8ms preprocess, 146.1ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 154.4ms
# Speed: 4.4ms preprocess, 154.4ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 151.7ms
# Speed: 3.2ms preprocess, 151.7ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 148.6ms
# Speed: 3.0ms preprocess, 148.6ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 152.2ms
# Speed: 4.0ms preprocess, 152.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 154.8ms
# Speed: 4.5ms preprocess, 154.8ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 152.8ms
# Speed: 3.5ms preprocess, 152.8ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 141.7ms
# Speed: 2.7ms preprocess, 141.7ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 149.7ms
# Speed: 3.1ms preprocess, 149.7ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 147.9ms
# Speed: 3.4ms preprocess, 147.9ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 154.8ms
# Speed: 4.1ms preprocess, 154.8ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 148.0ms
# Speed: 4.2ms preprocess, 148.0ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 148.0ms
# Speed: 3.7ms preprocess, 148.0ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 155.9ms
# Speed: 5.0ms preprocess, 155.9ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 141.0ms
# Speed: 4.6ms preprocess, 141.0ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 154.0ms
# Speed: 3.6ms preprocess, 154.0ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 152.9ms
# Speed: 6.1ms preprocess, 152.9ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 152.2ms
# Speed: 4.7ms preprocess, 152.2ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 153.9ms
# Speed: 6.4ms preprocess, 153.9ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 152.6ms
# Speed: 3.9ms preprocess, 152.6ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 153.8ms
# Speed: 3.1ms preprocess, 153.8ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 152.3ms
# Speed: 3.0ms preprocess, 152.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 147.2ms
# Speed: 3.1ms preprocess, 147.2ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 146.3ms
# Speed: 3.3ms preprocess, 146.3ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 148.0ms
# Speed: 3.2ms preprocess, 148.0ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 161.7ms
# Speed: 3.3ms preprocess, 161.7ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 149.6ms
# Speed: 3.7ms preprocess, 149.6ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 156.4ms
# Speed: 3.9ms preprocess, 156.4ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 147.2ms
# Speed: 3.8ms preprocess, 147.2ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 154.3ms
# Speed: 4.1ms preprocess, 154.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 146.8ms
# Speed: 4.1ms preprocess, 146.8ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 141.8ms
# Speed: 3.2ms preprocess, 141.8ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 151.5ms
# Speed: 3.6ms preprocess, 151.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 153.5ms
# Speed: 3.4ms preprocess, 153.5ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 146.9ms
# Speed: 5.0ms preprocess, 146.9ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 162.5ms
# Speed: 5.0ms preprocess, 162.5ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 161.3ms
# Speed: 4.1ms preprocess, 161.3ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 140.5ms
# Speed: 3.4ms preprocess, 140.5ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 151.3ms
# Speed: 3.7ms preprocess, 151.3ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 151.9ms
# Speed: 3.7ms preprocess, 151.9ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 154.5ms
# Speed: 5.0ms preprocess, 154.5ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 152.0ms
# Speed: 3.8ms preprocess, 152.0ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 160.6ms
# Speed: 3.0ms preprocess, 160.6ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 146.4ms
# Speed: 2.9ms preprocess, 146.4ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 154.7ms
# Speed: 4.1ms preprocess, 154.7ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 137.2ms
# Speed: 3.4ms preprocess, 137.2ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 154.8ms
# Speed: 2.9ms preprocess, 154.8ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 147.7ms
# Speed: 3.0ms preprocess, 147.7ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 156.2ms
# Speed: 4.1ms preprocess, 156.2ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 149.6ms
# Speed: 3.0ms preprocess, 149.6ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 153.7ms
# Speed: 2.9ms preprocess, 153.7ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 155.5ms
# Speed: 3.8ms preprocess, 155.5ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 147.6ms
# Speed: 3.6ms preprocess, 147.6ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 142.9ms
# Speed: 3.2ms preprocess, 142.9ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 155.2ms
# Speed: 3.7ms preprocess, 155.2ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 155.6ms
# Speed: 3.5ms preprocess, 155.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 149.4ms
# Speed: 3.0ms preprocess, 149.4ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 146.5ms
# Speed: 2.7ms preprocess, 146.5ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 152.6ms
# Speed: 4.8ms preprocess, 152.6ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 162.8ms
# Speed: 3.7ms preprocess, 162.8ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 151.9ms
# Speed: 3.9ms preprocess, 151.9ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 155.9ms
# Speed: 3.4ms preprocess, 155.9ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 186.1ms
# Speed: 6.3ms preprocess, 186.1ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 155.4ms
# Speed: 3.5ms preprocess, 155.4ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 154.5ms
# Speed: 3.7ms preprocess, 154.5ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 132.4ms
# Speed: 3.7ms preprocess, 132.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 156.9ms
# Speed: 3.4ms preprocess, 156.9ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 158.5ms
# Speed: 3.5ms preprocess, 158.5ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 133.4ms
# Speed: 3.5ms preprocess, 133.4ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 135.4ms
# Speed: 3.5ms preprocess, 135.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 143.1ms
# Speed: 4.2ms preprocess, 143.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 147.0ms
# Speed: 3.1ms preprocess, 147.0ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 149.6ms
# Speed: 4.0ms preprocess, 149.6ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 148.8ms
# Speed: 3.2ms preprocess, 148.8ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 156.3ms
# Speed: 3.4ms preprocess, 156.3ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 155.6ms
# Speed: 3.2ms preprocess, 155.6ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 151.4ms
# Speed: 3.7ms preprocess, 151.4ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 143.7ms
# Speed: 3.0ms preprocess, 143.7ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 157.6ms
# Speed: 6.0ms preprocess, 157.6ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 153.8ms
# Speed: 3.4ms preprocess, 153.8ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 154.5ms
# Speed: 3.2ms preprocess, 154.5ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 153.5ms
# Speed: 3.4ms preprocess, 153.5ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 146.4ms
# Speed: 3.7ms preprocess, 146.4ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 148.8ms
# Speed: 3.7ms preprocess, 148.8ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 152.2ms
# Speed: 3.3ms preprocess, 152.2ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 142.7ms
# Speed: 3.7ms preprocess, 142.7ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 158.0ms
# Speed: 4.1ms preprocess, 158.0ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 150.3ms
# Speed: 2.8ms preprocess, 150.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 153.2ms
# Speed: 3.5ms preprocess, 153.2ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 174.8ms
# Speed: 9.1ms preprocess, 174.8ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 158.2ms
# Speed: 4.0ms preprocess, 158.2ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 148.4ms
# Speed: 3.2ms preprocess, 148.4ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 145.9ms
# Speed: 2.7ms preprocess, 145.9ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 156.9ms
# Speed: 3.9ms preprocess, 156.9ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 156.2ms
# Speed: 3.1ms preprocess, 156.2ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 145.2ms
# Speed: 3.6ms preprocess, 145.2ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 149.7ms
# Speed: 3.5ms preprocess, 149.7ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 148.7ms
# Speed: 3.4ms preprocess, 148.7ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 154.3ms
# Speed: 3.6ms preprocess, 154.3ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 147.9ms
# Speed: 3.3ms preprocess, 147.9ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 154.2ms
# Speed: 3.5ms preprocess, 154.2ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 154.7ms
# Speed: 4.0ms preprocess, 154.7ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 146.0ms
# Speed: 3.6ms preprocess, 146.0ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 128.8ms
# Speed: 3.3ms preprocess, 128.8ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 159.1ms
# Speed: 3.2ms preprocess, 159.1ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 156.3ms
# Speed: 3.1ms preprocess, 156.3ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 155.9ms
# Speed: 4.4ms preprocess, 155.9ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 155.1ms
# Speed: 4.4ms preprocess, 155.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 156.7ms
# Speed: 3.1ms preprocess, 156.7ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 144.6ms
# Speed: 2.8ms preprocess, 144.6ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 153.3ms
# Speed: 3.3ms preprocess, 153.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 153.0ms
# Speed: 3.0ms preprocess, 153.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 154.2ms
# Speed: 3.7ms preprocess, 154.2ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 151.1ms
# Speed: 3.4ms preprocess, 151.1ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 148.2ms
# Speed: 2.9ms preprocess, 148.2ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 150.7ms
# Speed: 2.7ms preprocess, 150.7ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 146.7ms
# Speed: 2.6ms preprocess, 146.7ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 152.5ms
# Speed: 2.3ms preprocess, 152.5ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 155.4ms
# Speed: 3.5ms preprocess, 155.4ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 146.5ms
# Speed: 2.8ms preprocess, 146.5ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 150.3ms
# Speed: 3.3ms preprocess, 150.3ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 147.8ms
# Speed: 3.1ms preprocess, 147.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 153.8ms
# Speed: 3.8ms preprocess, 153.8ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 152.2ms
# Speed: 2.9ms preprocess, 152.2ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 148.6ms
# Speed: 3.5ms preprocess, 148.6ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 150.3ms
# Speed: 3.1ms preprocess, 150.3ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 147.5ms
# Speed: 3.3ms preprocess, 147.5ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 147.3ms
# Speed: 3.1ms preprocess, 147.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 155.5ms
# Speed: 3.6ms preprocess, 155.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 156.9ms
# Speed: 3.3ms preprocess, 156.9ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 147.9ms
# Speed: 3.5ms preprocess, 147.9ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 156.7ms
# Speed: 3.0ms preprocess, 156.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 151.7ms
# Speed: 3.3ms preprocess, 151.7ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 148.8ms
# Speed: 3.8ms preprocess, 148.8ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 138.1ms
# Speed: 2.9ms preprocess, 138.1ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 156.5ms
# Speed: 2.4ms preprocess, 156.5ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 156.5ms
# Speed: 3.5ms preprocess, 156.5ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 151.5ms
# Speed: 2.6ms preprocess, 151.5ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 156.1ms
# Speed: 3.8ms preprocess, 156.1ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 141.2ms
# Speed: 2.9ms preprocess, 141.2ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 148.7ms
# Speed: 3.4ms preprocess, 148.7ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 157.6ms
# Speed: 3.8ms preprocess, 157.6ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 163.8ms
# Speed: 4.1ms preprocess, 163.8ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 150.1ms
# Speed: 3.7ms preprocess, 150.1ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 149.5ms
# Speed: 3.6ms preprocess, 149.5ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 145.9ms
# Speed: 3.4ms preprocess, 145.9ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 154.4ms
# Speed: 5.1ms preprocess, 154.4ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 146.2ms
# Speed: 2.9ms preprocess, 146.2ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 152.2ms
# Speed: 2.6ms preprocess, 152.2ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 154.2ms
# Speed: 3.3ms preprocess, 154.2ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 146.9ms
# Speed: 3.5ms preprocess, 146.9ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 152.4ms
# Speed: 3.2ms preprocess, 152.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 152.8ms
# Speed: 2.7ms preprocess, 152.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 156.5ms
# Speed: 3.5ms preprocess, 156.5ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 155.6ms
# Speed: 3.4ms preprocess, 155.6ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 146.6ms
# Speed: 3.0ms preprocess, 146.6ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 155.4ms
# Speed: 4.6ms preprocess, 155.4ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 147.7ms
# Speed: 3.7ms preprocess, 147.7ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 150.3ms
# Speed: 4.4ms preprocess, 150.3ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 138.0ms
# Speed: 3.0ms preprocess, 138.0ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 156.8ms
# Speed: 2.5ms preprocess, 156.8ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 170.4ms
# Speed: 4.3ms preprocess, 170.4ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 149.3ms
# Speed: 4.7ms preprocess, 149.3ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 155.7ms
# Speed: 3.1ms preprocess, 155.7ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 146.6ms
# Speed: 3.3ms preprocess, 146.6ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 150.4ms
# Speed: 3.3ms preprocess, 150.4ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 147.2ms
# Speed: 2.8ms preprocess, 147.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 150.5ms
# Speed: 2.9ms preprocess, 150.5ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 147.1ms
# Speed: 2.9ms preprocess, 147.1ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 144.7ms
# Speed: 2.5ms preprocess, 144.7ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 153.1ms
# Speed: 3.8ms preprocess, 153.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 149.1ms
# Speed: 3.4ms preprocess, 149.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 158.6ms
# Speed: 3.9ms preprocess, 158.6ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 147.1ms
# Speed: 3.1ms preprocess, 147.1ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 147.7ms
# Speed: 3.0ms preprocess, 147.7ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 154.5ms
# Speed: 3.6ms preprocess, 154.5ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 145.1ms
# Speed: 2.4ms preprocess, 145.1ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 154.8ms
# Speed: 3.1ms preprocess, 154.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 150.7ms
# Speed: 3.2ms preprocess, 150.7ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 143.6ms
# Speed: 3.1ms preprocess, 143.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 147.0ms
# Speed: 3.4ms preprocess, 147.0ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 148.6ms
# Speed: 3.5ms preprocess, 148.6ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 151.9ms
# Speed: 3.3ms preprocess, 151.9ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 39.3ms
# Speed: 6.9ms preprocess, 39.3ms inference, 25.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 165.6ms
# Speed: 9.2ms preprocess, 165.6ms inference, 14.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 201.9ms
# Speed: 7.6ms preprocess, 201.9ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 145.1ms
# Speed: 3.0ms preprocess, 145.1ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 103.6ms
# Speed: 3.4ms preprocess, 103.6ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 98.6ms
# Speed: 9.2ms preprocess, 98.6ms inference, 18.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 235.2ms
# Speed: 6.7ms preprocess, 235.2ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 149.0ms
# Speed: 3.3ms preprocess, 149.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 153.3ms
# Speed: 5.2ms preprocess, 153.3ms inference, 9.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 56.8ms
# Speed: 7.6ms preprocess, 56.8ms inference, 20.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 154.3ms
# Speed: 4.8ms preprocess, 154.3ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 164.6ms
# Speed: 3.7ms preprocess, 164.6ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 138.5ms
# Speed: 3.8ms preprocess, 138.5ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 168.0ms
# Speed: 4.0ms preprocess, 168.0ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 163.8ms
# Speed: 6.3ms preprocess, 163.8ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 155.9ms
# Speed: 4.1ms preprocess, 155.9ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 155.8ms
# Speed: 4.1ms preprocess, 155.8ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 158.4ms
# Speed: 4.5ms preprocess, 158.4ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 153.9ms
# Speed: 6.3ms preprocess, 153.9ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 152.0ms
# Speed: 5.4ms preprocess, 152.0ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 160.0ms
# Speed: 5.3ms preprocess, 160.0ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 145.9ms
# Speed: 3.4ms preprocess, 145.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 159.4ms
# Speed: 4.3ms preprocess, 159.4ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 149.1ms
# Speed: 3.2ms preprocess, 149.1ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 151.7ms
# Speed: 4.2ms preprocess, 151.7ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 169.0ms
# Speed: 3.8ms preprocess, 169.0ms inference, 9.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 177.7ms
# Speed: 6.5ms preprocess, 177.7ms inference, 9.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 164.4ms
# Speed: 6.7ms preprocess, 164.4ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 169.4ms
# Speed: 4.6ms preprocess, 169.4ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 157.4ms
# Speed: 4.1ms preprocess, 157.4ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 160.7ms
# Speed: 6.1ms preprocess, 160.7ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 153.8ms
# Speed: 4.6ms preprocess, 153.8ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 168.4ms
# Speed: 5.7ms preprocess, 168.4ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 158.7ms
# Speed: 4.4ms preprocess, 158.7ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 158.6ms
# Speed: 5.4ms preprocess, 158.6ms inference, 9.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 186.3ms
# Speed: 10.3ms preprocess, 186.3ms inference, 12.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 179.8ms
# Speed: 9.5ms preprocess, 179.8ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 157.9ms
# Speed: 5.1ms preprocess, 157.9ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 173.4ms
# Speed: 8.3ms preprocess, 173.4ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 150.1ms
# Speed: 5.9ms preprocess, 150.1ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 159.2ms
# Speed: 5.0ms preprocess, 159.2ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 157.0ms
# Speed: 4.4ms preprocess, 157.0ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 149.9ms
# Speed: 4.0ms preprocess, 149.9ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 156.7ms
# Speed: 5.9ms preprocess, 156.7ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 158.6ms
# Speed: 4.2ms preprocess, 158.6ms inference, 9.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 205.8ms
# Speed: 5.5ms preprocess, 205.8ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 157.4ms
# Speed: 4.7ms preprocess, 157.4ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 154.6ms
# Speed: 4.4ms preprocess, 154.6ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 194.3ms
# Speed: 8.7ms preprocess, 194.3ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 202.1ms
# Speed: 7.9ms preprocess, 202.1ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 170.9ms
# Speed: 5.4ms preprocess, 170.9ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 164.0ms
# Speed: 5.6ms preprocess, 164.0ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 183.0ms
# Speed: 5.6ms preprocess, 183.0ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 169.2ms
# Speed: 4.2ms preprocess, 169.2ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 162.6ms
# Speed: 5.9ms preprocess, 162.6ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 164.7ms
# Speed: 3.1ms preprocess, 164.7ms inference, 10.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 187.5ms
# Speed: 5.9ms preprocess, 187.5ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 171.1ms
# Speed: 5.5ms preprocess, 171.1ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 161.8ms
# Speed: 4.8ms preprocess, 161.8ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 166.9ms
# Speed: 4.9ms preprocess, 166.9ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 175.3ms
# Speed: 3.7ms preprocess, 175.3ms inference, 11.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 167.4ms
# Speed: 4.1ms preprocess, 167.4ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 159.4ms
# Speed: 6.4ms preprocess, 159.4ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 181.1ms
# Speed: 5.9ms preprocess, 181.1ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 169.8ms
# Speed: 4.1ms preprocess, 169.8ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 155.3ms
# Speed: 4.7ms preprocess, 155.3ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 174.9ms
# Speed: 6.2ms preprocess, 174.9ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 190.4ms
# Speed: 4.0ms preprocess, 190.4ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 163.2ms
# Speed: 4.2ms preprocess, 163.2ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 173.6ms
# Speed: 4.6ms preprocess, 173.6ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 174.9ms
# Speed: 5.4ms preprocess, 174.9ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 164.7ms
# Speed: 4.2ms preprocess, 164.7ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 165.6ms
# Speed: 5.3ms preprocess, 165.6ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 167.1ms
# Speed: 5.1ms preprocess, 167.1ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 164.5ms
# Speed: 4.4ms preprocess, 164.5ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 167.0ms
# Speed: 5.3ms preprocess, 167.0ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 165.8ms
# Speed: 4.4ms preprocess, 165.8ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 166.5ms
# Speed: 5.2ms preprocess, 166.5ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 174.3ms
# Speed: 4.9ms preprocess, 174.3ms inference, 12.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 207.5ms
# Speed: 5.3ms preprocess, 207.5ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 174.3ms
# Speed: 11.6ms preprocess, 174.3ms inference, 9.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 169.6ms
# Speed: 6.0ms preprocess, 169.6ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 164.0ms
# Speed: 3.8ms preprocess, 164.0ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 177.8ms
# Speed: 4.9ms preprocess, 177.8ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 152.9ms
# Speed: 5.8ms preprocess, 152.9ms inference, 11.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 159.1ms
# Speed: 6.0ms preprocess, 159.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 163.6ms
# Speed: 3.6ms preprocess, 163.6ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 180.5ms
# Speed: 4.4ms preprocess, 180.5ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 181.5ms
# Speed: 5.5ms preprocess, 181.5ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 168.3ms
# Speed: 4.8ms preprocess, 168.3ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 149.8ms
# Speed: 4.9ms preprocess, 149.8ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 176.2ms
# Speed: 4.6ms preprocess, 176.2ms inference, 9.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 175.2ms
# Speed: 5.0ms preprocess, 175.2ms inference, 10.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 165.8ms
# Speed: 8.2ms preprocess, 165.8ms inference, 9.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 165.1ms
# Speed: 4.6ms preprocess, 165.1ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 166.0ms
# Speed: 4.5ms preprocess, 166.0ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 161.8ms
# Speed: 6.2ms preprocess, 161.8ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 176.7ms
# Speed: 5.5ms preprocess, 176.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 162.2ms
# Speed: 3.6ms preprocess, 162.2ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 167.0ms
# Speed: 4.5ms preprocess, 167.0ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 152.9ms
# Speed: 3.4ms preprocess, 152.9ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 154.3ms
# Speed: 4.8ms preprocess, 154.3ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 160.8ms
# Speed: 4.1ms preprocess, 160.8ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 151.3ms
# Speed: 3.7ms preprocess, 151.3ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 168.7ms
# Speed: 6.7ms preprocess, 168.7ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 167.0ms
# Speed: 5.3ms preprocess, 167.0ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 152.6ms
# Speed: 5.3ms preprocess, 152.6ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 164.1ms
# Speed: 5.1ms preprocess, 164.1ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 165.7ms
# Speed: 5.2ms preprocess, 165.7ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 166.6ms
# Speed: 5.9ms preprocess, 166.6ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 174.0ms
# Speed: 5.8ms preprocess, 174.0ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 173.5ms
# Speed: 5.5ms preprocess, 173.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 159.4ms
# Speed: 4.7ms preprocess, 159.4ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 158.4ms
# Speed: 4.1ms preprocess, 158.4ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 172.4ms
# Speed: 6.4ms preprocess, 172.4ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 159.8ms
# Speed: 5.4ms preprocess, 159.8ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 163.2ms
# Speed: 5.7ms preprocess, 163.2ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 152.1ms
# Speed: 4.8ms preprocess, 152.1ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 178.5ms
# Speed: 3.6ms preprocess, 178.5ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 159.2ms
# Speed: 4.6ms preprocess, 159.2ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 157.6ms
# Speed: 4.7ms preprocess, 157.6ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 160.7ms
# Speed: 3.1ms preprocess, 160.7ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 170.9ms
# Speed: 4.7ms preprocess, 170.9ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 157.2ms
# Speed: 4.6ms preprocess, 157.2ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 152.2ms
# Speed: 4.2ms preprocess, 152.2ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 155.2ms
# Speed: 4.4ms preprocess, 155.2ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 167.1ms
# Speed: 4.9ms preprocess, 167.1ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 162.3ms
# Speed: 5.6ms preprocess, 162.3ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 138.7ms
# Speed: 4.4ms preprocess, 138.7ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 161.1ms
# Speed: 5.8ms preprocess, 161.1ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 134.8ms
# Speed: 5.0ms preprocess, 134.8ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 109.6ms
# Speed: 6.3ms preprocess, 109.6ms inference, 14.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 120.2ms
# ...
# Speed: 4.6ms preprocess, 167.6ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 152.9ms
# Speed: 4.1ms preprocess, 152.9ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 163.9ms
# Speed: 3.6ms preprocess, 163.9ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 159.8ms
# Speed: 5.6ms preprocess, 159.8ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 148.2ms
# Speed: 3.6ms preprocess, 148.2ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 155.0ms
# Speed: 4.0ms preprocess, 155.0ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 164.3ms
# Speed: 4.7ms preprocess, 164.3ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 150.8ms
# Speed: 2.8ms preprocess, 150.8ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 172.0ms
# Speed: 4.3ms preprocess, 172.0ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 154.6ms
# Speed: 3.6ms preprocess, 154.6ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 167.8ms
# Speed: 3.6ms preprocess, 167.8ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 166.5ms
# Speed: 4.2ms preprocess, 166.5ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 169.9ms
# Speed: 7.0ms preprocess, 169.9ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 150.1ms
# Speed: 3.1ms preprocess, 150.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 152.3ms
# Speed: 3.2ms preprocess, 152.3ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 160.5ms
# Speed: 3.6ms preprocess, 160.5ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 159.7ms
# Speed: 4.9ms preprocess, 159.7ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 154.2ms
# Speed: 3.3ms preprocess, 154.2ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 172.2ms
# Speed: 5.5ms preprocess, 172.2ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 152.6ms
# Speed: 3.1ms preprocess, 152.6ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 152.1ms
# Speed: 4.2ms preprocess, 152.1ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 162.9ms
# Speed: 4.1ms preprocess, 162.9ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 154.5ms
# Speed: 4.9ms preprocess, 154.5ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 169.8ms
# Speed: 4.3ms preprocess, 169.8ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 162.2ms
# Speed: 4.5ms preprocess, 162.2ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 155.3ms
# Speed: 3.2ms preprocess, 155.3ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 147.2ms
# Speed: 3.9ms preprocess, 147.2ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 160.7ms
# Speed: 3.7ms preprocess, 160.7ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 158.6ms
# Speed: 5.0ms preprocess, 158.6ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 151.0ms
# Speed: 5.0ms preprocess, 151.0ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 139.6ms
# Speed: 2.8ms preprocess, 139.6ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 155.1ms
# Speed: 3.0ms preprocess, 155.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 152.8ms
# Speed: 3.1ms preprocess, 152.8ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 152.9ms
# Speed: 2.7ms preprocess, 152.9ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 152.4ms
# Speed: 4.8ms preprocess, 152.4ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 156.2ms
# Speed: 3.5ms preprocess, 156.2ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 147.9ms
# Speed: 3.3ms preprocess, 147.9ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 144.8ms
# Speed: 3.4ms preprocess, 144.8ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 152.9ms
# Speed: 3.8ms preprocess, 152.9ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 153.9ms
# Speed: 5.1ms preprocess, 153.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 146.0ms
# Speed: 3.2ms preprocess, 146.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 159.3ms
# Speed: 2.9ms preprocess, 159.3ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 152.8ms
# Speed: 3.0ms preprocess, 152.8ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 153.4ms
# Speed: 3.7ms preprocess, 153.4ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 145.8ms
# Speed: 3.0ms preprocess, 145.8ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 150.4ms
# Speed: 3.7ms preprocess, 150.4ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 155.9ms
# Speed: 2.6ms preprocess, 155.9ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 150.9ms
# Speed: 3.1ms preprocess, 150.9ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 154.1ms
# Speed: 3.1ms preprocess, 154.1ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 164.3ms
# Speed: 3.9ms preprocess, 164.3ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 155.7ms
# Speed: 4.7ms preprocess, 155.7ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 154.8ms
# Speed: 4.4ms preprocess, 154.8ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 155.9ms
# Speed: 4.0ms preprocess, 155.9ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 160.1ms
# Speed: 5.1ms preprocess, 160.1ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 157.2ms
# Speed: 4.0ms preprocess, 157.2ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 155.6ms
# Speed: 5.7ms preprocess, 155.6ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 147.6ms
# Speed: 4.0ms preprocess, 147.6ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 150.6ms
# Speed: 3.4ms preprocess, 150.6ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 161.6ms
# Speed: 5.5ms preprocess, 161.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 141.5ms
# Speed: 3.8ms preprocess, 141.5ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 162.1ms
# Speed: 3.5ms preprocess, 162.1ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 146.7ms
# Speed: 3.6ms preprocess, 146.7ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 161.0ms
# Speed: 3.6ms preprocess, 161.0ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 158.4ms
# Speed: 5.8ms preprocess, 158.4ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 156.3ms
# Speed: 2.9ms preprocess, 156.3ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 160.1ms
# Speed: 3.3ms preprocess, 160.1ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 146.9ms
# Speed: 4.6ms preprocess, 146.9ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 163.1ms
# Speed: 4.9ms preprocess, 163.1ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 154.0ms
# Speed: 4.2ms preprocess, 154.0ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 154.2ms
# Speed: 3.5ms preprocess, 154.2ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 146.6ms
# Speed: 3.3ms preprocess, 146.6ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 165.8ms
# Speed: 3.7ms preprocess, 165.8ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 153.4ms
# Speed: 4.5ms preprocess, 153.4ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 154.4ms
# Speed: 3.0ms preprocess, 154.4ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 149.3ms
# Speed: 2.9ms preprocess, 149.3ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 146.8ms
# Speed: 3.2ms preprocess, 146.8ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 152.8ms
# Speed: 4.3ms preprocess, 152.8ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 148.4ms
# Speed: 3.4ms preprocess, 148.4ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 152.4ms
# Speed: 3.7ms preprocess, 152.4ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 155.0ms
# Speed: 3.5ms preprocess, 155.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 159.6ms
# Speed: 3.2ms preprocess, 159.6ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 172.6ms
# Speed: 4.6ms preprocess, 172.6ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 154.3ms
# Speed: 3.5ms preprocess, 154.3ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 161.9ms
# Speed: 5.1ms preprocess, 161.9ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 152.5ms
# Speed: 4.3ms preprocess, 152.5ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 166.6ms
# Speed: 3.8ms preprocess, 166.6ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 156.3ms
# Speed: 4.5ms preprocess, 156.3ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 171.0ms
# Speed: 5.2ms preprocess, 171.0ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 154.1ms
# Speed: 3.8ms preprocess, 154.1ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 159.9ms
# Speed: 4.4ms preprocess, 159.9ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 153.0ms
# Speed: 2.9ms preprocess, 153.0ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 150.8ms
# Speed: 3.2ms preprocess, 150.8ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 160.6ms
# Speed: 3.2ms preprocess, 160.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 159.7ms
# Speed: 3.3ms preprocess, 159.7ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 155.9ms
# Speed: 3.0ms preprocess, 155.9ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 156.7ms
# Speed: 3.9ms preprocess, 156.7ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 153.4ms
# Speed: 5.7ms preprocess, 153.4ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 162.3ms
# Speed: 3.2ms preprocess, 162.3ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 164.8ms
# Speed: 4.5ms preprocess, 164.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 147.0ms
# Speed: 4.7ms preprocess, 147.0ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 157.1ms
# Speed: 3.8ms preprocess, 157.1ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 149.5ms
# Speed: 4.1ms preprocess, 149.5ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 155.8ms
# Speed: 3.3ms preprocess, 155.8ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 156.1ms
# Speed: 4.2ms preprocess, 156.1ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 165.1ms
# Speed: 4.3ms preprocess, 165.1ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 164.3ms
# Speed: 4.0ms preprocess, 164.3ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 164.1ms
# Speed: 5.1ms preprocess, 164.1ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 161.0ms
# Speed: 3.7ms preprocess, 161.0ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 158.8ms
# Speed: 2.8ms preprocess, 158.8ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 145.7ms
# Speed: 4.1ms preprocess, 145.7ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 148.4ms
# Speed: 3.2ms preprocess, 148.4ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 162.9ms
# Speed: 2.9ms preprocess, 162.9ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 149.3ms
# Speed: 3.6ms preprocess, 149.3ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 154.3ms
# Speed: 4.5ms preprocess, 154.3ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 150.2ms
# Speed: 3.7ms preprocess, 150.2ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 145.5ms
# Speed: 3.3ms preprocess, 145.5ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 170.3ms
# Speed: 3.4ms preprocess, 170.3ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 146.9ms
# Speed: 3.2ms preprocess, 146.9ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 156.1ms
# Speed: 3.1ms preprocess, 156.1ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 156.3ms
# Speed: 3.1ms preprocess, 156.3ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 144.9ms
# Speed: 2.9ms preprocess, 144.9ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 151.2ms
# Speed: 2.8ms preprocess, 151.2ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 150.6ms
# Speed: 3.9ms preprocess, 150.6ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 136.7ms
# Speed: 3.6ms preprocess, 136.7ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 151.2ms
# Speed: 5.4ms preprocess, 151.2ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pitch, 151.9ms
# Speed: 5.5ms preprocess, 151.9ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
# 0

# %%
# Add this function to detect possible pass receivers
def find_available_passes(frame, players, ball_holder, team_assignments):
    """
    Find all possible pass recipients for the player with the ball.
    Returns a list of (receiver_id, distance, is_clear) tuples.
    """
    if ball_holder is None or ball_holder not in team_assignments:
        return []
    
    holder_team = team_assignments[ball_holder]
    holder_idx = None
    for i, track_id in enumerate(players.tracker_id):
        if track_id == ball_holder:
            holder_idx = i
            break
    
    if holder_idx is None:
        return []
    
    holder_position = get_center_of_bbox(players.xyxy[holder_idx])
    available_passes = []
    
    # Find teammates
    for i, track_id in enumerate(players.tracker_id):
        if track_id != ball_holder and track_id in team_assignments and team_assignments[track_id] == holder_team:
            receiver_position = get_center_of_bbox(players.xyxy[i])
            distance = np.linalg.norm(np.array(holder_position) - np.array(receiver_position))
            
            # Check if pass is clear (no opponents in the way)
            is_clear = True
            for j, other_id in enumerate(players.tracker_id):
                if other_id in team_assignments and team_assignments[other_id] != holder_team:
                    opponent_position = get_center_of_bbox(players.xyxy[j])
                    if is_point_on_line_segment(holder_position, receiver_position, opponent_position, tolerance=30):
                        is_clear = False
                        break
            
            available_passes.append((track_id, distance, is_clear))
    
    return available_passes

# Add this helper function to check if a point is between two other points
def is_point_on_line_segment(p1, p2, p3, tolerance=20):
    """
    Check if point p3 is on the line segment from p1 to p2 within a tolerance.
    """
    # Convert to numpy arrays for easier operations
    p1 = np.array(p1)
    p2 = np.array(p2)
    p3 = np.array(p3)
    
    # Calculate distance from p3 to the line segment from p1 to p2
    line_length = np.linalg.norm(p2 - p1)
    if line_length == 0:
        return np.linalg.norm(p3 - p1) <= tolerance
    
    # Project p3 onto the line
    t = np.dot(p3 - p1, p2 - p1) / (line_length * line_length)
    
    # Check if projection is on the segment
    if 0 <= t <= 1:
        projection = p1 + t * (p2 - p1)
        distance = np.linalg.norm(p3 - projection)
        return distance <= tolerance
    
    return False

# Function to draw pass lines
def draw_pass_lines(frame, players, available_passes, team_color):
    """
    Draw lines representing available passes on the frame.
    Green lines for clear passes, red lines for blocked passes.
    """
    holder_idx = None
    for i, track_id in enumerate(players.tracker_id):
        if track_id == ball_holder:
            holder_idx = i
            break
    
    if holder_idx is None:
        return frame
    
    holder_position = get_center_of_bbox(players.xyxy[holder_idx])
    
    for receiver_id, distance, is_clear in available_passes:
        for i, track_id in enumerate(players.tracker_id):
            if track_id == receiver_id:
                receiver_position = get_center_of_bbox(players.xyxy[i])
                color = (0, 255, 0) if is_clear else (0, 0, 255)  # Green for clear, red for blocked
                thickness = 2 if distance < 150 else 1  # Thicker lines for closer players
                
                # Draw the pass line
                cv2.line(frame, 
                    (int(holder_position[0]), int(holder_position[1])),
                    (int(receiver_position[0]), int(receiver_position[1])),
                    color, thickness)
                
                # Draw a small circle at the end to indicate the receiver
                cv2.circle(frame, 
                    (int(receiver_position[0]), int(receiver_position[1])),
                    5, color, -1)
    
    return frame

# %%
	# Add these functions to analyze zone control

def divide_field_into_zones(width, height, zones_x=3, zones_y=2):
    """
    Divide the field into a grid of zones.
    Returns a list of (x1, y1, x2, y2) coordinates for each zone.
    """
    zone_width = width // zones_x
    zone_height = height // zones_y
    zones = []
    
    for y in range(zones_y):
        for x in range(zones_x):
            x1 = x * zone_width
            y1 = y * zone_height
            x2 = (x + 1) * zone_width
            y2 = (y + 1) * zone_height
            zones.append((x1, y1, x2, y2))
    
    return zones

def get_player_zone(player_center, zones):
    """
    Determine which zone a player is in based on their position.
    Returns the zone index.
    """
    x, y = player_center
    for i, (x1, y1, x2, y2) in enumerate(zones):
        if x1 <= x <= x2 and y1 <= y <= y2:
            return i
    return None

def analyze_zone_control(players, team_assignments, zones):
    """
    Analyze which team controls each zone.
    Returns a dictionary mapping zone index to (team1_count, team2_count, dominant_team).
    """
    zone_control = {}
    for i in range(len(zones)):
        zone_control[i] = {0: 0, 1: 0, "dominant": None}
    
    for i, track_id in enumerate(players.tracker_id):
        if track_id in team_assignments:
            player_center = get_center_of_bbox(players.xyxy[i])
            zone = get_player_zone(player_center, zones)
            if zone is not None:
                team = team_assignments[track_id]
                zone_control[zone][team] += 1
    
    # Determine dominant team for each zone
    for zone in zone_control:
        team1_count = zone_control[zone][0]
        team2_count = zone_control[zone][1]
        
        if team1_count > team2_count:
            zone_control[zone]["dominant"] = 0
        elif team2_count > team1_count:
            zone_control[zone]["dominant"] = 1
        else:
            zone_control[zone]["dominant"] = None  # Tie
    
    return zone_control

def draw_zone_control(frame, zones, zone_control, team_colors):
    """
    Visualize zone control by overlaying semi-transparent colors on the field.
    """
    overlay = frame.copy()
    
    for zone_idx, (x1, y1, x2, y2) in enumerate(zones):
        dominant_team = zone_control[zone_idx]["dominant"]
        team1_count = zone_control[zone_idx][0]
        team2_count = zone_control[zone_idx][1]
        
        # Draw zone outline
        cv2.rectangle(frame, (x1, y1), (x2, y2), (255, 255, 255), 2)
        
        # Add zone number
        cv2.putText(frame, f"Zone {zone_idx+1}", (x1+10, y1+25), 
                   cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 255), 2)
        
        # Determine overlay color based on dominant team
        if dominant_team is not None:
            color = team_colors[dominant_team]
            # Calculate opacity based on dominance
            total_players = team1_count + team2_count
            if total_players > 0:
                dominance_ratio = max(team1_count, team2_count) / total_players
                opacity = 0.2 + (0.3 * dominance_ratio)  # Between 0.2 and 0.5
            else:
                opacity = 0.2
                
            # Draw filled rectangle with team color
            cv2.rectangle(overlay, (x1, y1), (x2, y2), color, -1)
            
            # Add player count
            text = f"{team1_count}:{team2_count}"
            cv2.putText(overlay, text, (x1+10, y1+60), 
                       cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 255), 2)
    
    # Blend the overlay with the original frame
    cv2.addWeighted(overlay, 0.3, frame, 0.7, 0, frame)
    
    return frame

def add_zone_control_legend(frame, width, height, team_colors):
    """
    Add a legend explaining the zone control visualization
    """
    # Create a semi-transparent background for the legend
    legend_x1 = 10
    legend_y1 = 10
    legend_x2 = 250
    legend_y2 = 100
    frame = add_transparent_rectangle(frame, legend_x1, legend_y1, legend_x2, legend_y2, (0, 0, 0), 0.7)
    
    # Add title
    cv2.putText(frame, "Zone Control Legend:", (legend_x1 + 10, legend_y1 + 30), 
               cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 1)
    
    # Add team colors
    cv2.rectangle(frame, (legend_x1 + 10, legend_y1 + 40), (legend_x1 + 30, legend_y1 + 60), team_colors[0], -1)
    cv2.putText(frame, "Team 1", (legend_x1 + 40, legend_y1 + 55), 
               cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 1)
    
    cv2.rectangle(frame, (legend_x1 + 10, legend_y1 + 70), (legend_x1 + 30, legend_y1 + 90), team_colors[1], -1)
    cv2.putText(frame, "Team 2", (legend_x1 + 40, legend_y1 + 85), 
               cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 1)
    
    return frame

# %%
import cv2
import numpy as np
import os
from ultralytics import YOLO
from collections import defaultdict
from sklearn.cluster import KMeans
import supervision as sv
from classifiers import *
from visualization import *
from utils import *
from interpolations import  *

# paths
input_video_path = 'input_videos/9.mp4'
output_video_path = 'output_videos/output.mp4'
model_path = 'models/best.pt'

# making video and readung 
cap = cv2.VideoCapture(input_video_path)
fps = cap.get(cv2.CAP_PROP_FPS)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
out = cv2.VideoWriter(output_video_path, cv2.VideoWriter_fourcc(*'mp4v'), fps, (width, height))

model = YOLO(model_path)
tracker = sv.ByteTrack()
# Add these variables at the start of your script, with the other variables
zones = None
zone_control = None


# possession variables
team_possession = {0: 0, 1: 0}
current_possession = None
ball_holder = None
ball_hold_frames = 0
possession_threshold = 5
total_frames = 0

# additional variables
reference_colors = None
team_assignments = {}
color_history = defaultdict(list)
ball_positions_history = []
max_history_length = 10

# Team colors
TEAM_COLORS = {
    0: (0, 0, 255),  # Team 1 - Red
    1: (255, 0, 0),  # Team 2 - Blue
    "goalkeeper": (0, 0, 255),
    "referee": (0, 255, 255),
    "ball": (255, 255, 255)
}

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Step 1 detection 
    results = model(frame)[0]
    detections = sv.Detections.from_ultralytics(results)
    players = detections[detections.class_id == 2]
    goalkeepers = detections[detections.class_id == 1]
    referees = detections[detections.class_id == 3]
    ball = detections[detections.class_id == 0]

    # Step 2 classification based on jerse color 
    if len(players) > 0:
        grass_color = get_grass_color(frame)
        grass_hsv = cv2.cvtColor(np.uint8([[grass_color]]), cv2.COLOR_BGR2HSV)[0, 0]
        jersey_colors = [
            get_jersey_color(frame[int(y1):int(y2), int(x1):int(x2)], grass_hsv)
            for x1, y1, x2, y2 in players.xyxy
        ]
        
        # detect the team colors
        if len(jersey_colors) >= 2 and not reference_colors:
            kmeans = KMeans(n_clusters=2).fit(jersey_colors)
            reference_colors = {
                0: kmeans.cluster_centers_[0],
                1: kmeans.cluster_centers_[1],
            }

        # ربط اللاعبين بفرقهم
        teams = []
        for color in jersey_colors:
            if reference_colors:
                distances = [np.linalg.norm(color - ref) for ref in reference_colors.values()]
                team = distances.index(min(distances))
                teams.append(team)

    # Step 3 tracking 
    players = tracker.update_with_detections(players)

    for i, track_id in enumerate(players.tracker_id):
        if i < len(teams):
            color_history[track_id].append(teams[i])
            if len(color_history[track_id]) >= 5:
                assigned_team = max(set(color_history[track_id]), key=color_history[track_id].count)
                team_assignments[track_id] = assigned_team

    # Step 4 ball position interpolation 
    ball_bbox = None
    if len(ball.xyxy) > 0:
        ball_bbox = tuple(map(int, ball.xyxy[0]))
        ball_positions_history.append(ball_bbox)
    else:
        ball_positions_history.append(None)

    if len(ball_positions_history) > max_history_length:
        ball_positions_history.pop(0)

    if None in ball_positions_history:
        interpolated = interpolate_ball_positions(ball_positions_history)
        if interpolated[-1]:
            ball_bbox = interpolated[-1]

    #Step 5  calculate possession 
    zones = divide_field_into_zones(width, height, zones_x=3, zones_y=2)
    annotated = frame.copy()

    # Add this inside your main loop, before drawing
    # Calculate zone control
    if len(players.tracker_id) > 0:
        zone_control = analyze_zone_control(players, team_assignments, zones)

    # Then add this to your drawing section:
# Draw zone control visualization (add this before drawing players)
    if zone_control:
        annotated = draw_zone_control(annotated, zones, zone_control, TEAM_COLORS)
        annotated = add_zone_control_legend(annotated, width, height, TEAM_COLORS)
        closest_player = None
        min_distance = float('inf')

    if ball_bbox:
        ball_center = get_center_of_bbox(ball_bbox)
        for i, track_id in enumerate(players.tracker_id):
            player_center = get_center_of_bbox(players.xyxy[i])
            dist = np.linalg.norm(np.array(ball_center) - np.array(player_center))
            if dist < min_distance and dist < 40:
                min_distance = dist
                closest_player = track_id

        if closest_player:
            if closest_player == ball_holder:
                ball_hold_frames += 1
            else:
                ball_holder = closest_player
                ball_hold_frames = 1

            if ball_hold_frames >= possession_threshold:
                new_possession = team_assignments.get(ball_holder, None)
                if new_possession is not None:
                    current_possession = new_possession
                    team_possession[current_possession] += 1

    total_frames += 1
    available_passes = []
    if ball_holder and ball_holder in team_assignments:
        available_passes = find_available_passes(frame, players, ball_holder, team_assignments)
    

    # Step 6 drawing 
    


    # draw players
    for bbox, track_id in zip(players.xyxy, players.tracker_id):
        team = team_assignments.get(track_id, 0)
        has_ball = (track_id == ball_holder and ball_hold_frames >= possession_threshold)
        annotated = draw_annotation(annotated, bbox, TEAM_COLORS[team], track_id, team, has_ball)

    # draw ball
    if ball_bbox:
        draw_triangle(annotated, ball_bbox, TEAM_COLORS["ball"])

    # Draw possession
    if total_frames > 0:
        team_0_ratio = team_possession[0] / total_frames
        team_1_ratio = team_possession[1] / total_frames
        total_ratio = team_0_ratio + team_1_ratio
        team_0_possession = (team_0_ratio / total_ratio) * 100 if total_ratio > 0 else 50
        team_1_possession = 100 - team_0_possession

        possession_text = f"Team {current_possession + 1} has possession" if current_possession is not None else "No possession"
        annotated = add_transparent_rectangle(annotated, width - 400, height - 130, width - 10, height - 10, (192, 192, 192), 0.7)
        cv2.putText(annotated, f"Team 1: {team_0_possession:.1f}%", (width - 350, height - 100), cv2.FONT_HERSHEY_SIMPLEX, 1, TEAM_COLORS[0], 2)
        cv2.putText(annotated, f"Team 2: {team_1_possession:.1f}%", (width - 350, height - 60), cv2.FONT_HERSHEY_SIMPLEX, 1, TEAM_COLORS[1], 2)
        cv2.putText(annotated, possession_text, (width - 350, height - 20), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 255, 255), 2)
    
    if ball_holder and ball_holder in team_assignments:
        team = team_assignments[ball_holder]
        annotated = draw_pass_lines(annotated, players, available_passes, TEAM_COLORS[team],ball_holder=ball_holder)
    
    # Add pass statistics to the display (optional)
    if ball_holder and available_passes:
        clear_passes = sum(1 for _, _, is_clear in available_passes if is_clear)
        cv2.putText(annotated, 
                    f"Clear passes: {clear_passes}/{len(available_passes)}", 
                    (50, height - 20), 
                    cv2.FONT_HERSHEY_SIMPLEX, 
                    0.8, (255, 255, 255), 2)
 
    out.write(annotated)

cap.release()
out.release()
print("✅ Processing complete.")
os.system(f'start {output_video_path}')
# Out:
# 0: 384x640 2 goalkeepers, 17 players, 4 referees, 35.9ms
# Speed: 2.3ms preprocess, 35.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 20 players, 3 referees, 34.4ms
# Speed: 3.9ms preprocess, 34.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 20 players, 3 referees, 34.8ms
# Speed: 2.3ms preprocess, 34.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 18 players, 3 referees, 34.6ms
# Speed: 2.1ms preprocess, 34.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 17 players, 2 referees, 34.4ms
# Speed: 2.1ms preprocess, 34.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 18 players, 2 referees, 35.2ms
# Speed: 2.5ms preprocess, 35.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 19 players, 1 referee, 35.2ms
# Speed: 2.5ms preprocess, 35.2ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 20 players, 1 referee, 35.0ms
# Speed: 3.1ms preprocess, 35.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 20 players, 1 referee, 35.5ms
# Speed: 3.1ms preprocess, 35.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 18 players, 2 referees, 34.4ms
# Speed: 2.6ms preprocess, 34.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 20 players, 1 referee, 34.1ms
# Speed: 2.6ms preprocess, 34.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 18 players, 2 referees, 34.2ms
# Speed: 2.6ms preprocess, 34.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 15 players, 2 referees, 35.4ms
# Speed: 2.6ms preprocess, 35.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 15 players, 2 referees, 34.6ms
# Speed: 2.6ms preprocess, 34.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 14 players, 2 referees, 34.6ms
# Speed: 2.3ms preprocess, 34.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 16 players, 2 referees, 34.5ms
# Speed: 2.0ms preprocess, 34.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 15 players, 1 referee, 34.4ms
# Speed: 2.0ms preprocess, 34.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 17 players, 1 referee, 37.0ms
# Speed: 2.3ms preprocess, 37.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 15 players, 1 referee, 37.1ms
# Speed: 2.4ms preprocess, 37.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 16 players, 1 referee, 39.0ms
# Speed: 2.4ms preprocess, 39.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 2 goalkeepers, 18 players, 1 referee, 37.2ms
# Speed: 2.7ms preprocess, 37.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 15 players, 1 referee, 37.4ms
# Speed: 2.4ms preprocess, 37.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 17 players, 2 referees, 37.6ms
# Speed: 1.9ms preprocess, 37.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 18 players, 3 referees, 37.5ms
# Speed: 2.2ms preprocess, 37.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 2 goalkeepers, 19 players, 2 referees, 37.6ms
# Speed: 2.1ms preprocess, 37.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 19 players, 2 referees, 38.1ms
# Speed: 2.1ms preprocess, 38.1ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 2 referees, 39.2ms
# Speed: 2.3ms preprocess, 39.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 2 goalkeepers, 18 players, 2 referees, 38.3ms
# Speed: 2.7ms preprocess, 38.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 17 players, 3 referees, 38.6ms
# Speed: 2.1ms preprocess, 38.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 17 players, 2 referees, 38.7ms
# Speed: 2.0ms preprocess, 38.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 17 players, 2 referees, 38.6ms
# Speed: 2.0ms preprocess, 38.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 2 goalkeepers, 19 players, 3 referees, 38.9ms
# Speed: 2.1ms preprocess, 38.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 20 players, 3 referees, 39.4ms
# Speed: 2.6ms preprocess, 39.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 2 goalkeepers, 20 players, 3 referees, 38.7ms
# Speed: 2.9ms preprocess, 38.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 19 players, 3 referees, 39.0ms
# Speed: 2.1ms preprocess, 39.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 2 goalkeepers, 18 players, 3 referees, 39.3ms
# Speed: 2.5ms preprocess, 39.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 2 goalkeepers, 17 players, 3 referees, 39.3ms
# Speed: 2.4ms preprocess, 39.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 19 players, 3 referees, 39.9ms
# Speed: 3.6ms preprocess, 39.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 19 players, 3 referees, 39.4ms
# Speed: 2.8ms preprocess, 39.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 18 players, 3 referees, 39.5ms
# Speed: 2.1ms preprocess, 39.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 2 referees, 39.5ms
# Speed: 2.7ms preprocess, 39.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 20 players, 2 referees, 41.2ms
# Speed: 2.5ms preprocess, 41.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 2 goalkeepers, 20 players, 2 referees, 39.9ms
# Speed: 2.1ms preprocess, 39.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 20 players, 2 referees, 40.5ms
# Speed: 1.9ms preprocess, 40.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 19 players, 2 referees, 40.7ms
# Speed: 2.0ms preprocess, 40.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 18 players, 2 referees, 40.3ms
# Speed: 2.1ms preprocess, 40.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 18 players, 3 referees, 41.0ms
# Speed: 2.4ms preprocess, 41.0ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 17 players, 3 referees, 42.1ms
# Speed: 2.1ms preprocess, 42.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 17 players, 3 referees, 40.3ms
# Speed: 2.1ms preprocess, 40.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 2 goalkeepers, 18 players, 3 referees, 40.7ms
# Speed: 2.0ms preprocess, 40.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 17 players, 3 referees, 42.4ms
# Speed: 2.3ms preprocess, 42.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 2 goalkeepers, 17 players, 3 referees, 40.4ms
# Speed: 2.2ms preprocess, 40.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 2 goalkeepers, 18 players, 4 referees, 40.1ms
# Speed: 2.4ms preprocess, 40.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 19 players, 3 referees, 41.7ms
# Speed: 2.6ms preprocess, 41.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 19 players, 3 referees, 40.3ms
# Speed: 2.5ms preprocess, 40.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 18 players, 3 referees, 40.3ms
# Speed: 2.2ms preprocess, 40.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 17 players, 3 referees, 40.2ms
# Speed: 2.2ms preprocess, 40.2ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 17 players, 3 referees, 40.5ms
# Speed: 2.4ms preprocess, 40.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 19 players, 3 referees, 40.9ms
# Speed: 2.5ms preprocess, 40.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 19 players, 3 referees, 41.9ms
# Speed: 2.3ms preprocess, 41.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 19 players, 3 referees, 40.1ms
# Speed: 2.1ms preprocess, 40.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 18 players, 3 referees, 40.0ms
# Speed: 2.7ms preprocess, 40.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 19 players, 3 referees, 41.1ms
# Speed: 3.2ms preprocess, 41.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 18 players, 3 referees, 40.5ms
# Speed: 2.2ms preprocess, 40.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 20 players, 3 referees, 41.8ms
# Speed: 2.3ms preprocess, 41.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 18 players, 3 referees, 40.7ms
# Speed: 3.0ms preprocess, 40.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 2 goalkeepers, 17 players, 2 referees, 41.0ms
# Speed: 2.5ms preprocess, 41.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 2 goalkeepers, 18 players, 3 referees, 42.2ms
# Speed: 2.1ms preprocess, 42.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 18 players, 3 referees, 40.8ms
# Speed: 2.3ms preprocess, 40.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 19 players, 3 referees, 41.8ms
# Speed: 4.5ms preprocess, 41.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 2 goalkeepers, 19 players, 3 referees, 40.6ms
# Speed: 2.3ms preprocess, 40.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 19 players, 3 referees, 42.0ms
# Speed: 2.6ms preprocess, 42.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 18 players, 3 referees, 40.4ms
# Speed: 2.4ms preprocess, 40.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 18 players, 3 referees, 40.2ms
# Speed: 2.7ms preprocess, 40.2ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 2 goalkeepers, 18 players, 2 referees, 40.3ms
# Speed: 2.2ms preprocess, 40.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 20 players, 2 referees, 40.3ms
# Speed: 2.2ms preprocess, 40.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 21 players, 2 referees, 40.4ms
# Speed: 2.5ms preprocess, 40.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 20 players, 2 referees, 40.2ms
# Speed: 2.5ms preprocess, 40.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 20 players, 2 referees, 42.4ms
# Speed: 2.6ms preprocess, 42.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 18 players, 2 referees, 40.5ms
# Speed: 2.5ms preprocess, 40.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 1 referee, 40.8ms
# Speed: 3.2ms preprocess, 40.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 2 referees, 40.4ms
# Speed: 2.6ms preprocess, 40.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 16 players, 3 referees, 40.3ms
# Speed: 4.8ms preprocess, 40.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 17 players, 3 referees, 40.3ms
# Speed: 2.5ms preprocess, 40.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 17 players, 3 referees, 40.7ms
# Speed: 3.4ms preprocess, 40.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 3 referees, 40.2ms
# Speed: 2.2ms preprocess, 40.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 3 referees, 40.4ms
# Speed: 2.2ms preprocess, 40.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 20 players, 3 referees, 40.0ms
# Speed: 2.4ms preprocess, 40.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 20 players, 3 referees, 40.6ms
# Speed: 3.2ms preprocess, 40.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 20 players, 3 referees, 41.8ms
# Speed: 2.7ms preprocess, 41.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 20 players, 3 referees, 41.5ms
# Speed: 2.3ms preprocess, 41.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 19 players, 3 referees, 41.3ms
# Speed: 2.8ms preprocess, 41.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 18 players, 3 referees, 41.7ms
# Speed: 2.7ms preprocess, 41.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 3 referees, 40.6ms
# Speed: 2.1ms preprocess, 40.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 42.9ms
# Speed: 2.3ms preprocess, 42.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 40.4ms
# Speed: 2.1ms preprocess, 40.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 3 referees, 40.2ms
# Speed: 2.2ms preprocess, 40.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 3 referees, 40.6ms
# Speed: 2.4ms preprocess, 40.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 3 referees, 40.4ms
# Speed: 2.1ms preprocess, 40.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 3 referees, 41.8ms
# Speed: 2.1ms preprocess, 41.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 18 players, 3 referees, 40.6ms
# Speed: 2.3ms preprocess, 40.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 3 referees, 40.1ms
# Speed: 2.5ms preprocess, 40.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 3 referees, 42.5ms
# Speed: 2.8ms preprocess, 42.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 3 referees, 40.5ms
# Speed: 2.5ms preprocess, 40.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 3 referees, 40.3ms
# Speed: 2.4ms preprocess, 40.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 3 referees, 42.1ms
# Speed: 2.7ms preprocess, 42.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 2 referees, 40.6ms
# Speed: 2.6ms preprocess, 40.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 2 referees, 42.0ms
# Speed: 2.4ms preprocess, 42.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 3 referees, 40.3ms
# Speed: 2.2ms preprocess, 40.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 3 referees, 40.2ms
# Speed: 2.4ms preprocess, 40.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 3 referees, 40.3ms
# Speed: 3.1ms preprocess, 40.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 3 referees, 40.5ms
# Speed: 2.8ms preprocess, 40.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 3 referees, 42.9ms
# Speed: 2.4ms preprocess, 42.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 3 referees, 40.4ms
# Speed: 2.2ms preprocess, 40.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 3 referees, 40.1ms
# Speed: 2.3ms preprocess, 40.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 3 referees, 40.3ms
# Speed: 3.2ms preprocess, 40.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 3 referees, 40.5ms
# Speed: 2.2ms preprocess, 40.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 3 referees, 40.3ms
# Speed: 2.2ms preprocess, 40.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 3 referees, 40.6ms
# Speed: 2.7ms preprocess, 40.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 3 referees, 40.0ms
# Speed: 2.3ms preprocess, 40.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 3 referees, 41.2ms
# Speed: 4.4ms preprocess, 41.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 19 players, 3 referees, 40.3ms
# Speed: 2.6ms preprocess, 40.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 3 referees, 40.6ms
# Speed: 2.4ms preprocess, 40.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 39.9ms
# Speed: 2.3ms preprocess, 39.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 40.1ms
# Speed: 2.1ms preprocess, 40.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 21 players, 3 referees, 40.1ms
# Speed: 2.1ms preprocess, 40.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 40.4ms
# Speed: 2.3ms preprocess, 40.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 2 referees, 40.4ms
# Speed: 2.7ms preprocess, 40.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 21 players, 3 referees, 40.3ms
# Speed: 2.6ms preprocess, 40.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 3 referees, 39.8ms
# Speed: 2.0ms preprocess, 39.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 3 referees, 40.1ms
# Speed: 2.0ms preprocess, 40.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 41.8ms
# Speed: 2.1ms preprocess, 41.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 2 referees, 40.8ms
# Speed: 2.5ms preprocess, 40.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 41.0ms
# Speed: 2.4ms preprocess, 41.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 41.5ms
# Speed: 2.1ms preprocess, 41.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 3 referees, 42.6ms
# Speed: 2.2ms preprocess, 42.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 41.9ms
# Speed: 3.4ms preprocess, 41.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 42.0ms
# Speed: 2.3ms preprocess, 42.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 40.5ms
# Speed: 2.1ms preprocess, 40.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 40.7ms
# Speed: 2.4ms preprocess, 40.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 42.3ms
# Speed: 2.3ms preprocess, 42.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 1 referee, 41.1ms
# Speed: 2.5ms preprocess, 41.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 39.9ms
# Speed: 2.4ms preprocess, 39.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 41.6ms
# Speed: 2.3ms preprocess, 41.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 40.0ms
# Speed: 2.6ms preprocess, 40.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 40.3ms
# Speed: 2.2ms preprocess, 40.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 40.0ms
# Speed: 2.7ms preprocess, 40.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 42.3ms
# Speed: 2.6ms preprocess, 42.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 40.6ms
# Speed: 2.6ms preprocess, 40.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 2 referees, 40.4ms
# Speed: 3.9ms preprocess, 40.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 42.1ms
# Speed: 2.3ms preprocess, 42.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 40.4ms
# Speed: 2.7ms preprocess, 40.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 40.2ms
# Speed: 2.7ms preprocess, 40.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 42.0ms
# Speed: 2.4ms preprocess, 42.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 40.4ms
# Speed: 2.3ms preprocess, 40.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 40.8ms
# Speed: 2.3ms preprocess, 40.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 1 referee, 40.4ms
# Speed: 2.9ms preprocess, 40.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 39.9ms
# Speed: 2.0ms preprocess, 39.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 40.2ms
# Speed: 2.1ms preprocess, 40.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 40.8ms
# Speed: 2.5ms preprocess, 40.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 40.4ms
# Speed: 2.6ms preprocess, 40.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 42.0ms
# Speed: 2.5ms preprocess, 42.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 40.5ms
# Speed: 2.1ms preprocess, 40.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 40.1ms
# Speed: 2.3ms preprocess, 40.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 40.3ms
# Speed: 2.3ms preprocess, 40.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 41.0ms
# Speed: 2.3ms preprocess, 41.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 1 referee, 40.2ms
# Speed: 2.2ms preprocess, 40.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 40.1ms
# Speed: 2.1ms preprocess, 40.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 1 referee, 40.5ms
# Speed: 2.9ms preprocess, 40.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 1 referee, 40.2ms
# Speed: 2.7ms preprocess, 40.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 40.5ms
# Speed: 2.2ms preprocess, 40.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 40.2ms
# Speed: 2.3ms preprocess, 40.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 40.6ms
# Speed: 2.1ms preprocess, 40.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 40.3ms
# Speed: 2.5ms preprocess, 40.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 40.6ms
# Speed: 2.2ms preprocess, 40.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 40.2ms
# Speed: 2.2ms preprocess, 40.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 40.1ms
# Speed: 2.0ms preprocess, 40.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 41.7ms
# Speed: 3.0ms preprocess, 41.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 21 players, 2 referees, 41.7ms
# Speed: 4.0ms preprocess, 41.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 41.6ms
# Speed: 2.7ms preprocess, 41.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 2 referees, 40.6ms
# Speed: 2.6ms preprocess, 40.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 2 referees, 41.0ms
# Speed: 2.2ms preprocess, 41.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 2 referees, 42.5ms
# Speed: 2.2ms preprocess, 42.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 2 referees, 41.2ms
# Speed: 2.3ms preprocess, 41.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 2 referees, 42.7ms
# Speed: 2.3ms preprocess, 42.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 2 referees, 40.1ms
# Speed: 2.3ms preprocess, 40.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 40.3ms
# Speed: 2.2ms preprocess, 40.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 2 referees, 40.1ms
# Speed: 2.7ms preprocess, 40.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 39.9ms
# Speed: 3.4ms preprocess, 39.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 40.0ms
# Speed: 1.9ms preprocess, 40.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 40.7ms
# Speed: 2.7ms preprocess, 40.7ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 40.6ms
# Speed: 2.4ms preprocess, 40.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 41.7ms
# Speed: 2.3ms preprocess, 41.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 40.5ms
# Speed: 2.6ms preprocess, 40.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 20 players, 1 referee, 40.4ms
# Speed: 2.2ms preprocess, 40.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 42.4ms
# Speed: 2.6ms preprocess, 42.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 20 players, 1 referee, 40.2ms
# Speed: 3.1ms preprocess, 40.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 20 players, 1 referee, 39.9ms
# Speed: 2.1ms preprocess, 39.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 39.7ms
# Speed: 2.1ms preprocess, 39.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 40.1ms
# Speed: 2.0ms preprocess, 40.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 20 players, 1 referee, 40.0ms
# Speed: 2.3ms preprocess, 40.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 19 players, 1 referee, 42.5ms
# Speed: 2.2ms preprocess, 42.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 19 players, 1 referee, 39.9ms
# Speed: 2.5ms preprocess, 39.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 1 referee, 40.1ms
# Speed: 2.4ms preprocess, 40.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 40.2ms
# Speed: 2.7ms preprocess, 40.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 40.1ms
# Speed: 2.3ms preprocess, 40.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 40.0ms
# Speed: 2.4ms preprocess, 40.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 41.5ms
# Speed: 3.2ms preprocess, 41.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 40.2ms
# Speed: 2.5ms preprocess, 40.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 41.6ms
# Speed: 2.3ms preprocess, 41.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 40.1ms
# Speed: 2.0ms preprocess, 40.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 40.8ms
# Speed: 2.9ms preprocess, 40.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 41.7ms
# Speed: 2.2ms preprocess, 41.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 1 referee, 42.4ms
# Speed: 3.9ms preprocess, 42.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 18 players, 1 referee, 42.1ms
# Speed: 2.7ms preprocess, 42.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 40.7ms
# Speed: 2.3ms preprocess, 40.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 40.9ms
# Speed: 2.4ms preprocess, 40.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 40.5ms
# Speed: 4.5ms preprocess, 40.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 40.6ms
# Speed: 2.1ms preprocess, 40.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 42.2ms
# Speed: 2.4ms preprocess, 42.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 40.5ms
# Speed: 2.5ms preprocess, 40.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 2 referees, 42.4ms
# Speed: 2.7ms preprocess, 42.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 2 referees, 40.4ms
# Speed: 2.3ms preprocess, 40.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 40.2ms
# Speed: 2.4ms preprocess, 40.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 40.5ms
# Speed: 2.5ms preprocess, 40.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 40.6ms
# Speed: 2.2ms preprocess, 40.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 40.1ms
# Speed: 2.1ms preprocess, 40.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 41.6ms
# Speed: 2.5ms preprocess, 41.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 40.3ms
# Speed: 2.1ms preprocess, 40.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 40.2ms
# Speed: 2.5ms preprocess, 40.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 40.4ms
# Speed: 2.0ms preprocess, 40.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 39.9ms
# Speed: 2.8ms preprocess, 39.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 40.4ms
# Speed: 2.6ms preprocess, 40.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 42.0ms
# Speed: 2.3ms preprocess, 42.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 1 referee, 40.4ms
# Speed: 2.7ms preprocess, 40.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 1 referee, 40.3ms
# Speed: 2.0ms preprocess, 40.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 40.3ms
# Speed: 2.3ms preprocess, 40.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 40.4ms
# Speed: 2.2ms preprocess, 40.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 18 players, 2 referees, 40.3ms
# Speed: 2.5ms preprocess, 40.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 17 players, 2 referees, 40.3ms
# Speed: 2.2ms preprocess, 40.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 18 players, 2 referees, 40.2ms
# Speed: 2.3ms preprocess, 40.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 40.5ms
# Speed: 2.3ms preprocess, 40.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 40.3ms
# Speed: 2.3ms preprocess, 40.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 40.1ms
# Speed: 2.6ms preprocess, 40.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 40.5ms
# Speed: 2.7ms preprocess, 40.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 42.4ms
# Speed: 2.3ms preprocess, 42.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 20 players, 2 referees, 45.4ms
# Speed: 2.4ms preprocess, 45.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 2 referees, 41.0ms
# Speed: 2.6ms preprocess, 41.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 18 players, 2 referees, 42.8ms
# Speed: 2.3ms preprocess, 42.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 18 players, 2 referees, 41.5ms
# Speed: 2.2ms preprocess, 41.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 17 players, 1 referee, 40.7ms
# Speed: 2.3ms preprocess, 40.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 18 players, 1 referee, 42.2ms
# Speed: 2.4ms preprocess, 42.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 1 referee, 42.7ms
# Speed: 3.0ms preprocess, 42.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 2 referees, 40.2ms
# Speed: 2.5ms preprocess, 40.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 2 referees, 42.3ms
# Speed: 2.3ms preprocess, 42.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 2 referees, 40.2ms
# Speed: 2.6ms preprocess, 40.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 2 referees, 40.2ms
# Speed: 2.4ms preprocess, 40.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 40.6ms
# Speed: 2.5ms preprocess, 40.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 40.4ms
# Speed: 2.4ms preprocess, 40.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 40.2ms
# Speed: 2.4ms preprocess, 40.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 40.2ms
# Speed: 2.4ms preprocess, 40.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 41.0ms
# Speed: 2.6ms preprocess, 41.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 2 referees, 40.8ms
# Speed: 2.8ms preprocess, 40.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 19 players, 2 referees, 40.4ms
# Speed: 3.1ms preprocess, 40.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 2 referees, 40.4ms
# Speed: 2.6ms preprocess, 40.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 41.0ms
# Speed: 3.3ms preprocess, 41.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 42.7ms
# Speed: 2.7ms preprocess, 42.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 40.1ms
# Speed: 3.2ms preprocess, 40.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 40.1ms
# Speed: 2.5ms preprocess, 40.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 40.1ms
# Speed: 3.4ms preprocess, 40.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 40.6ms
# Speed: 3.7ms preprocess, 40.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 40.4ms
# Speed: 2.7ms preprocess, 40.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 40.5ms
# Speed: 3.6ms preprocess, 40.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 2 referees, 40.4ms
# Speed: 4.6ms preprocess, 40.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 2 referees, 40.5ms
# Speed: 3.4ms preprocess, 40.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 42.1ms
# Speed: 2.7ms preprocess, 42.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 19 players, 2 referees, 40.2ms
# Speed: 2.3ms preprocess, 40.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 43.1ms
# Speed: 4.1ms preprocess, 43.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 40.5ms
# Speed: 2.7ms preprocess, 40.5ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 42.3ms
# Speed: 3.6ms preprocess, 42.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 39.9ms
# Speed: 2.3ms preprocess, 39.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 42.6ms
# Speed: 2.4ms preprocess, 42.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 2 referees, 42.6ms
# Speed: 2.8ms preprocess, 42.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 19 players, 2 referees, 41.1ms
# Speed: 3.2ms preprocess, 41.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 41.3ms
# Speed: 2.5ms preprocess, 41.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 42.5ms
# Speed: 2.6ms preprocess, 42.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 41.3ms
# Speed: 2.7ms preprocess, 41.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 40.8ms
# Speed: 2.3ms preprocess, 40.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 2 referees, 41.0ms
# Speed: 3.0ms preprocess, 41.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 2 referees, 40.7ms
# Speed: 2.6ms preprocess, 40.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 42.4ms
# Speed: 2.9ms preprocess, 42.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 41.0ms
# Speed: 2.7ms preprocess, 41.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 2 referees, 43.0ms
# Speed: 2.9ms preprocess, 43.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 40.2ms
# Speed: 2.3ms preprocess, 40.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 41.5ms
# Speed: 2.3ms preprocess, 41.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 40.4ms
# Speed: 2.6ms preprocess, 40.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 41.3ms
# Speed: 2.6ms preprocess, 41.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 40.1ms
# Speed: 2.6ms preprocess, 40.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 42.4ms
# Speed: 2.9ms preprocess, 42.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 40.1ms
# Speed: 2.2ms preprocess, 40.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 40.1ms
# Speed: 2.5ms preprocess, 40.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 40.3ms
# Speed: 2.8ms preprocess, 40.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 40.8ms
# Speed: 2.1ms preprocess, 40.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 40.0ms
# Speed: 2.3ms preprocess, 40.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 41.8ms
# Speed: 2.5ms preprocess, 41.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 2 referees, 39.7ms
# Speed: 2.3ms preprocess, 39.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 39.8ms
# Speed: 2.5ms preprocess, 39.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 41.9ms
# Speed: 3.3ms preprocess, 41.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 40.2ms
# Speed: 2.5ms preprocess, 40.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 40.0ms
# Speed: 2.4ms preprocess, 40.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 40.5ms
# Speed: 3.4ms preprocess, 40.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 40.3ms
# Speed: 2.7ms preprocess, 40.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 40.8ms
# Speed: 3.5ms preprocess, 40.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 39.9ms
# Speed: 2.4ms preprocess, 39.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 40.0ms
# Speed: 2.5ms preprocess, 40.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 41.0ms
# Speed: 2.5ms preprocess, 41.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 39.6ms
# Speed: 2.4ms preprocess, 39.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 40.2ms
# Speed: 2.7ms preprocess, 40.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 40.5ms
# Speed: 2.5ms preprocess, 40.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# ...
#
# 0: 384x640 1 ball, 20 players, 2 referees, 40.7ms
# Speed: 2.6ms preprocess, 40.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 1 referee, 40.4ms
# Speed: 3.1ms preprocess, 40.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 40.7ms
# Speed: 2.7ms preprocess, 40.7ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 41.5ms
# Speed: 5.4ms preprocess, 41.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 40.8ms
# Speed: 2.9ms preprocess, 40.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 43.6ms
# Speed: 5.1ms preprocess, 43.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 41.0ms
# Speed: 3.8ms preprocess, 41.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 40.7ms
# Speed: 3.4ms preprocess, 40.7ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 42.1ms
# Speed: 4.4ms preprocess, 42.1ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 41.2ms
# Speed: 4.0ms preprocess, 41.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 42.6ms
# Speed: 4.3ms preprocess, 42.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 41.2ms
# Speed: 3.0ms preprocess, 41.2ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 42.0ms
# Speed: 5.3ms preprocess, 42.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 2 referees, 41.1ms
# Speed: 3.9ms preprocess, 41.1ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 1 referee, 40.6ms
# Speed: 2.6ms preprocess, 40.6ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 40.4ms
# Speed: 2.7ms preprocess, 40.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 2 referees, 41.1ms
# Speed: 4.8ms preprocess, 41.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 40.8ms
# Speed: 2.7ms preprocess, 40.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 40.7ms
# Speed: 3.0ms preprocess, 40.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 40.8ms
# Speed: 2.9ms preprocess, 40.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 2 referees, 43.9ms
# Speed: 2.7ms preprocess, 43.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 56.8ms
# Speed: 7.9ms preprocess, 56.8ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 2 referees, 47.1ms
# Speed: 3.7ms preprocess, 47.1ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 48.8ms
# Speed: 5.1ms preprocess, 48.8ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 2 referees, 52.1ms
# Speed: 5.5ms preprocess, 52.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 2 referees, 56.1ms
# Speed: 5.2ms preprocess, 56.1ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 2 referees, 54.6ms
# Speed: 4.0ms preprocess, 54.6ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 2 referees, 52.7ms
# Speed: 3.4ms preprocess, 52.7ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 54.1ms
# Speed: 2.6ms preprocess, 54.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 55.6ms
# Speed: 2.4ms preprocess, 55.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 2 referees, 46.7ms
# Speed: 4.1ms preprocess, 46.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 46.6ms
# Speed: 3.3ms preprocess, 46.6ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 46.9ms
# Speed: 3.5ms preprocess, 46.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 46.5ms
# Speed: 2.7ms preprocess, 46.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 1 referee, 48.8ms
# Speed: 4.2ms preprocess, 48.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 47.7ms
# Speed: 3.7ms preprocess, 47.7ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 2 referees, 48.4ms
# Speed: 6.0ms preprocess, 48.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 48.0ms
# Speed: 4.0ms preprocess, 48.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 46.4ms
# Speed: 4.4ms preprocess, 46.4ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 46.5ms
# Speed: 2.6ms preprocess, 46.5ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 48.2ms
# Speed: 3.9ms preprocess, 48.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 21 players, 1 referee, 49.2ms
# Speed: 3.1ms preprocess, 49.2ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 2 referees, 49.8ms
# Speed: 2.6ms preprocess, 49.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 45.6ms
# Speed: 2.6ms preprocess, 45.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 2 referees, 44.1ms
# Speed: 3.1ms preprocess, 44.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 1 referee, 44.5ms
# Speed: 2.7ms preprocess, 44.5ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 1 referee, 41.9ms
# Speed: 5.3ms preprocess, 41.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 45.1ms
# Speed: 4.8ms preprocess, 45.1ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 1 referee, 42.5ms
# Speed: 3.7ms preprocess, 42.5ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 41.6ms
# Speed: 2.8ms preprocess, 41.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 1 referee, 42.0ms
# Speed: 3.2ms preprocess, 42.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 42.4ms
# Speed: 3.1ms preprocess, 42.4ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 41.7ms
# Speed: 3.5ms preprocess, 41.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 41.7ms
# Speed: 3.5ms preprocess, 41.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 41.9ms
# Speed: 3.6ms preprocess, 41.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 43.9ms
# Speed: 3.3ms preprocess, 43.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 41.3ms
# Speed: 2.5ms preprocess, 41.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 41.9ms
# Speed: 2.5ms preprocess, 41.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 3 referees, 43.1ms
# Speed: 4.7ms preprocess, 43.1ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 3 referees, 41.1ms
# Speed: 2.8ms preprocess, 41.1ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 3 referees, 41.8ms
# Speed: 6.2ms preprocess, 41.8ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 3 referees, 40.7ms
# Speed: 3.9ms preprocess, 40.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 3 referees, 43.0ms
# Speed: 4.7ms preprocess, 43.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 3 referees, 40.7ms
# Speed: 3.6ms preprocess, 40.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 3 referees, 42.3ms
# Speed: 2.7ms preprocess, 42.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 19 players, 3 referees, 42.4ms
# Speed: 3.4ms preprocess, 42.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 players, 3 referees, 43.1ms
# Speed: 3.0ms preprocess, 43.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 41.2ms
# Speed: 4.0ms preprocess, 41.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 21 players, 3 referees, 41.2ms
# Speed: 3.4ms preprocess, 41.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 3 referees, 47.9ms
# Speed: 3.6ms preprocess, 47.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 49.8ms
# Speed: 3.3ms preprocess, 49.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 43.4ms
# Speed: 3.5ms preprocess, 43.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 44.4ms
# Speed: 3.1ms preprocess, 44.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 44.7ms
# Speed: 2.8ms preprocess, 44.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 42.0ms
# Speed: 2.6ms preprocess, 42.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 3 referees, 41.7ms
# Speed: 3.1ms preprocess, 41.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 42.3ms
# Speed: 3.8ms preprocess, 42.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 41.5ms
# Speed: 2.9ms preprocess, 41.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 41.6ms
# Speed: 3.2ms preprocess, 41.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 41.8ms
# Speed: 3.9ms preprocess, 41.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 42.5ms
# Speed: 4.9ms preprocess, 42.5ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 3 referees, 42.1ms
# Speed: 3.3ms preprocess, 42.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 3 referees, 42.0ms
# Speed: 5.6ms preprocess, 42.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 41.4ms
# Speed: 3.7ms preprocess, 41.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 41.1ms
# Speed: 2.5ms preprocess, 41.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 19 players, 3 referees, 43.7ms
# Speed: 5.6ms preprocess, 43.7ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 3 referees, 41.7ms
# Speed: 3.3ms preprocess, 41.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 40.8ms
# Speed: 3.1ms preprocess, 40.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 40.8ms
# Speed: 2.7ms preprocess, 40.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 40.8ms
# Speed: 3.2ms preprocess, 40.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 42.1ms
# Speed: 3.4ms preprocess, 42.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 44.4ms
# Speed: 5.1ms preprocess, 44.4ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 3 referees, 41.8ms
# Speed: 4.9ms preprocess, 41.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 3 referees, 41.3ms
# Speed: 2.9ms preprocess, 41.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 20 players, 3 referees, 40.6ms
# Speed: 3.3ms preprocess, 40.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 40.3ms
# Speed: 3.0ms preprocess, 40.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 55.0ms
# Speed: 3.3ms preprocess, 55.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 45.0ms
# Speed: 4.1ms preprocess, 45.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 43.0ms
# Speed: 5.4ms preprocess, 43.0ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 52.9ms
# Speed: 11.2ms preprocess, 52.9ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 40.8ms
# Speed: 2.8ms preprocess, 40.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 41.4ms
# Speed: 4.7ms preprocess, 41.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 40.3ms
# Speed: 3.7ms preprocess, 40.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 2 referees, 40.4ms
# Speed: 2.9ms preprocess, 40.4ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 2 referees, 47.4ms
# Speed: 3.3ms preprocess, 47.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 48.4ms
# Speed: 2.4ms preprocess, 48.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 3 referees, 46.6ms
# Speed: 2.7ms preprocess, 46.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 42.6ms
# Speed: 2.8ms preprocess, 42.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 43.5ms
# Speed: 3.9ms preprocess, 43.5ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 43.0ms
# Speed: 3.2ms preprocess, 43.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 42.6ms
# Speed: 3.0ms preprocess, 42.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 players, 3 referees, 42.6ms
# Speed: 2.7ms preprocess, 42.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Processing complete.
# 0
